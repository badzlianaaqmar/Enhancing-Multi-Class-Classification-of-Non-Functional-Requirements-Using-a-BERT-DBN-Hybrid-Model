# %%
# !pip install scikit-optimize
# Out:
# Collecting scikit-optimize
#   Downloading scikit_optimize-0.10.2-py2.py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.11/dist-packages (from scikit-optimize) (1.4.2)
# Collecting pyaml>=16.9 (from scikit-optimize)
#   Downloading pyaml-25.1.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: numpy>=1.20.3 in /usr/local/lib/python3.11/dist-packages (from scikit-optimize) (1.26.4)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-optimize) (1.13.1)
# Requirement already satisfied: scikit-learn>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from scikit-optimize) (1.6.0)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.11/dist-packages (from scikit-optimize) (24.2)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from pyaml>=16.9->scikit-optimize) (6.0.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.0.0->scikit-optimize) (3.5.0)
# Downloading scikit_optimize-0.10.2-py2.py3-none-any.whl (107 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.8/107.8 kB 4.6 MB/s eta 0:00:00
# Downloading pyaml-25.1.0-py3-none-any.whl (26 kB)
# Installing collected packages: pyaml, scikit-optimize
# Successfully installed pyaml-25.1.0 scikit-optimize-0.10.2

# %%
import pandas as pd
import numpy as np
from transformers import BertTokenizer, BertModel
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import classification_report
from skopt import gp_minimize
from skopt.space import Real, Integer
from skopt.utils import use_named_args

# %%
data=pd.read_csv('/content/drive/MyDrive/databersih.csv')
data.head()
# Out:
#                                      requirementtext  class_encoded
# 0  the system shall refresh the display every 60 ...              1
# 1  if projected the data must be readable on a 10...              3
# 2  if projected the data must be understandable o...              3
# 3  the product shall ensure that it can only be a...              2
# 4  the product shall be intuitive and selfexplana...              3

# %%
data.head(1)
# Out:
#                                      requirementtext  class_encoded
# 0  the system shall refresh the display every 60 ...              1

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 741 entries, 0 to 740
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   requirementtext  741 non-null    object
#  1   class_encoded    741 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 11.7+ KB

# %%
# Check for duplicate rows
duplicate_rows = data.duplicated()

# Count duplicates
num_duplicates = duplicate_rows.sum()

# Show duplicates if any
duplicates = data[duplicate_rows]

num_duplicates, duplicates
# Out:
# (167,
#                                         requirementtext  class_encoded
#  314  if a user account is revoked it can only be re...              2
#  318  the product must support internet explorer 55 ...              0
#  319  the product must support mozilla firefox 10 an...              0
#  344  the product must work with most database manag...              0
#  404  the website will use standard internet convent...              3
#  ..                                                 ...            ...
#  730  the application shall be able to complete ever...              1
#  731  the application shall run on a web application...              0
#  732  a primary database will be used to store cache...              0
#  733  a secondary database will be used to store his...              0
#  737  only authorized user shall access the rfs syst...              2
#
#  [167 rows x 2 columns])

# %%
# Remove duplicate rows
data_no_duplicates = data.drop_duplicates()

# Check the number of rows after removing duplicates
rows_after_removal = data_no_duplicates.shape[0]

rows_after_removal
# Out:
# 574

# %%
# Rename the cleaned dataset variable
data = data_no_duplicates

# Display the first few rows of the renamed dataset
data.head()
# Out:
#                                      requirementtext  class_encoded
# 0  the system shall refresh the display every 60 ...              1
# 1  if projected the data must be readable on a 10...              3
# 2  if projected the data must be understandable o...              3
# 3  the product shall ensure that it can only be a...              2
# 4  the product shall be intuitive and selfexplana...              3

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 574 entries, 0 to 740
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   requirementtext  574 non-null    object
#  1   class_encoded    574 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 13.5+ KB

# %%
# !pip install transformers torch
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.47.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.5.1+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.27.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2024.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.11/dist-packages (from torch) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.11/dist-packages (from torch) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.11/dist-packages (from torch) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.11/dist-packages (from torch) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.11/dist-packages (from torch) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.11/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch) (12.6.85)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2024.12.14)

# %%
import torch
from transformers import BertTokenizer, BertModel

# Load BERT tokenizer dan model
tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")
model = BertModel.from_pretrained("bert-base-uncased")

# Fungsi untuk mendapatkan embedding BERT
def get_bert_embedding(text):
    inputs = tokenizer(text, return_tensors="pt", truncation=True, padding=True, max_length=512)
    with torch.no_grad():
        outputs = model(**inputs)
        cls_embedding = outputs.last_hidden_state[:, 0, :].squeeze(0)
    return cls_embedding.numpy()

# Generate BERT embedding
print("Menghasilkan embedding BERT...")
data['bert_embedding'] = data['requirementtext'].apply(lambda x: get_bert_embedding(x))

# Cek hasil embedding untuk satu data
print("Hasil embedding untuk satu data:")
print(data['bert_embedding'].iloc[0])

# Konversi data ke Tensor
X = torch.tensor(data['bert_embedding'].tolist(), dtype=torch.float32)
y = torch.tensor(data['class_encoded'].tolist(), dtype=torch.long)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Menghasilkan embedding BERT...
# Hasil embedding untuk satu data:
# [-2.33651936e-01  2.94205397e-01  4.20726180e-01 -1.94514439e-01
#  -4.72817710e-03 -4.49977487e-01  4.62353587e-01  4.86323535e-01
#   8.93407762e-02 -3.14982623e-01 -3.41054827e-01 -2.54376009e-02
#  -1.18047602e-01  2.37434566e-01  2.94608772e-01  8.16140100e-02
#  -4.54770923e-02  3.68105203e-01  1.00082301e-01 -6.95243925e-02
#  -3.98903966e-01 -3.81839991e-01  1.77327052e-01  6.65141195e-02
#   4.11189087e-02 -1.39258131e-01  1.14860259e-01  2.08792374e-01
#  -1.41547084e-01  1.04330808e-01  2.92083830e-01  1.52185550e-02
#  -1.09238245e-01 -8.34477693e-02  1.45114958e-01 -6.76671267e-02
#  -6.48890436e-02  1.66975319e-01  4.79960404e-02  2.77985603e-01
#   1.14043064e-01  1.98079184e-01  4.88096058e-01 -2.04499990e-01
#   3.23102832e-01 -4.82340962e-01 -2.30179405e+00 -2.56694168e-01
#   5.03919125e-02  2.98904199e-02  1.91988781e-01  3.53302970e-03
#  -1.74163774e-01  2.76577473e-01  1.91961348e-01  3.78287174e-02
#  -5.68843663e-01  6.15382195e-01  1.45521909e-01  1.96610793e-01
#   2.63050258e-01 -2.68030584e-01  2.71550007e-02  3.02097052e-01
#   1.12782065e-02  1.74153652e-02  1.17171809e-01 -3.21199112e-02
#   7.77754188e-02  3.92645270e-01 -2.78341204e-01  2.19775569e-02
#   4.19797182e-01  2.09325612e-01  8.77511650e-02 -4.38322127e-01
#  -2.97698736e-01  1.09037176e-01 -3.48880202e-01  1.30364336e-02
#   1.34964092e-02  3.28002542e-01  2.54883349e-01 -6.78277463e-02
#  -9.92473736e-02  3.89772564e-01 -1.19335257e-01 -9.98988077e-02
#   3.70902866e-01  7.46405244e-01 -2.07102850e-01  3.37137640e-01
#  -8.35315138e-02  1.26344785e-01  1.29354626e-01 -2.08689705e-01
#  -3.40433329e-01  5.32642938e-03  4.01828259e-01  1.03382044e-01
#   2.56455511e-01  1.11795425e-01  2.69275699e-02 -4.06065941e-01
#   1.07552461e-01 -4.33464758e-02 -2.54812241e-01 -3.45458090e-01
#   2.41359621e-01 -2.50653815e+00  2.30087936e-01  8.53028074e-02
#  -3.17019373e-01 -9.63481292e-02 -1.06511883e-01  4.47899669e-01
#   3.68883431e-01 -1.41118675e-01  1.28277540e-01  9.75586325e-02
#   1.58574089e-01  4.30162370e-01  4.60088998e-02 -3.08367968e-01
#   2.24884704e-01  3.34211797e-01  5.75860739e-01  2.20793441e-01
#   1.19398512e-01  1.82131156e-01 -1.59429640e-01  3.97727847e-01
#   1.24002151e-01 -3.49796303e-02 -2.26781189e-01  4.04309556e-02
#   4.86593395e-01 -4.09579605e-01  3.23226936e-02  1.73914611e-01
#  -3.71581495e-01 -2.71794468e-01 -2.78163195e+00  1.17998607e-01
#   3.10243070e-01  4.85044792e-02 -1.08248442e-01  8.34506005e-02
#   1.34664506e-01  4.36784387e-01  1.22411400e-01  3.16540301e-01
#  -2.37438098e-01 -4.40012366e-02 -3.53506535e-01 -4.77489233e-01
#  -2.54986972e-01 -2.16944497e-02  8.79771858e-02  2.06279948e-01
#   3.97212029e-01  2.14673892e-01 -1.45646587e-01 -1.70033604e-01
#  -2.23025471e-01  1.51729673e-01  2.81283170e-01  4.79267925e-01
#   2.86748588e-01 -3.60802591e-01 -5.76944798e-02 -1.75088570e-01
#  -7.27562513e-03  2.77436435e-01  2.60245770e-01 -2.38273144e-01
#   1.95405319e-01  3.90422016e-01 -1.54918030e-01 -3.21645766e-01
#  -3.90775234e-01  3.06085765e-01  1.18544027e-01  1.97777197e-01
#   2.64193147e-01 -3.28777730e-01  5.01367688e-01 -1.33132324e-01
#  -2.45539725e-01  2.06332996e-01 -1.58574075e-01 -2.19757497e-01
#   1.04292734e-02 -4.80513051e-02  5.13045788e-01  3.54232849e-03
#   2.00017512e-01 -6.48669183e-01  3.07368100e-01  6.07896566e-01
#   1.38246477e-01  8.19384530e-02 -1.07975654e-01 -1.20662667e-01
#  -3.09435636e-01  3.62263012e+00  1.56095885e-02 -4.24206972e-01
#   2.65011072e-01  3.38615030e-02 -1.49169460e-01  1.21066347e-01
#  -9.86825898e-02 -4.64213580e-01  9.32388678e-02 -2.34715372e-01
#   2.94875026e-01  2.54160576e-02 -6.95263147e-02 -1.62059292e-01
#   2.41899878e-01  3.29533577e-01 -6.93531940e-03  2.31781930e-01
#  -3.42150509e-01 -2.99931973e-01 -1.22954004e-01  9.06147838e-01
#  -1.47731364e-01 -1.39912546e+00 -1.85524538e-01 -1.65414914e-01
#  -1.54847205e-01  4.89000112e-01 -3.44615668e-01 -8.74403268e-02
#   1.00335190e-02 -1.15796514e-01  1.81689397e-01  1.78599656e-01
#   2.00938150e-01  2.75240362e-01  5.45728691e-02 -1.12233609e-01
#  -7.90418163e-02  4.09385115e-01  1.64452702e-01 -3.24973613e-02
#  -5.19441478e-02 -8.90559107e-02  4.06932116e-01 -4.27043736e-01
#   6.78692609e-02 -4.35250521e-01 -3.33944291e-01 -6.88877106e-02
#   1.68745995e-01  8.20937157e-02 -5.03547251e-01 -1.84988737e-01
#  -3.33998621e-01 -6.94450662e-02  3.44999999e-01  7.25089107e-04
#  -1.59919783e-01 -7.95794010e-01  1.65674582e-01 -2.24500373e-01
#   4.97492030e-03  2.10066629e-03 -1.07642189e-02 -1.59236759e-01
#  -2.39087999e-01 -3.90842032e+00  7.09743053e-02 -1.47040561e-02
#   6.49137855e-01  4.55325752e-01 -1.72029182e-01  3.79872680e-01
#   1.45535588e-01 -1.38890266e-01 -4.58461791e-01  6.81491256e-01
#   4.67992276e-01  1.61050946e-01  2.29824871e-01 -7.17293441e-01
#   1.98348403e-01 -6.25324808e-03 -2.20453262e-01 -2.47141272e-01
#   1.31910548e-01  1.23822995e-01  1.93716109e-01 -2.04445019e-01
#  -7.94332549e-02 -1.59394234e-01  2.60857612e-01 -6.70260936e-02
#  -7.30176568e-02  3.50432238e-03 -6.81054890e-02 -8.29409137e-02
#  -1.33945540e-01 -2.24620089e-01 -3.80568355e-01 -2.19674870e-01
#  -3.61533713e+00 -6.64631799e-02 -3.16472620e-01 -1.43012539e-01
#   9.82406959e-02 -7.57183060e-02  5.76789975e-01  1.56110898e-01
#  -2.05067880e-02  1.69910103e-01 -9.49410424e-02  2.02485412e-01
#   1.78136930e-01  1.59694284e-01  1.78545326e-01  1.61291301e-01
#   4.33544368e-01 -2.39979044e-01  1.42934933e-01 -3.94576266e-02
#  -1.73237771e-01 -3.28875333e-01 -2.27951944e-01 -9.59586799e-02
#   2.27129832e-01  6.42212555e-02 -2.93260068e-01 -8.36704448e-02
#   1.10643348e-02  1.16710775e-01 -4.29183282e-02 -1.02389105e-01
#  -2.22339511e-01 -2.34122034e-02 -3.12706321e-01 -3.82564127e-01
#  -1.43003508e-01  2.61756450e-01  2.70423383e-01 -1.53247029e-01
#   1.57083392e-01  5.07489383e-01 -6.44771904e-02  2.80923396e-01
#   2.12043568e-01  9.31187272e-02  6.31845593e-02 -1.44517571e-01
#   2.94753879e-01  2.14345306e-01 -1.23523556e-01  1.38571262e-01
#   1.30841076e+00 -1.32361621e-01 -3.16663593e-01  4.75662202e-02
#   4.51490462e-01  1.95844755e-01 -6.24219468e-03  1.90290153e-01
#   3.01240921e-01 -2.87253261e-01  3.26199353e-01  1.25537679e-01
#   7.99937919e-02 -9.32633877e-02  2.26849943e-01 -3.48903060e-01
#  -2.37360075e-01  1.88800525e-02 -1.35426581e-01  4.28716421e-01
#   2.17423551e-02 -6.54922307e-01 -3.03596228e-01 -1.68730132e-02
#  -7.61139169e-02  2.33410001e-01  1.20044269e-01 -1.32624939e-01
#  -3.52103353e-01 -1.33301586e-01 -1.39274240e-01  3.08222711e-01
#  -1.94437221e-01 -8.06104485e-03  3.69570106e-02  1.32290311e-02
#  -1.84172243e-01  2.01191939e-02 -5.27386852e-02 -7.63687268e-02
#   1.48287088e-01  1.75420299e-01 -3.64834249e-01 -4.59259041e-02
#   1.81809977e-01 -7.05048680e-01  7.38335624e-02 -1.05730020e-01
#  -1.27283514e-01 -2.34840065e-01 -1.45915418e-03 -1.25869080e-01
#  -2.31758714e-01 -3.32929827e-02  1.67987600e-01 -4.10373136e-02
#  -7.32697695e-02  2.41592318e-01 -2.52464890e-01 -1.92782599e-02
#   7.26741850e-02  1.45104051e-01  9.25726354e-01 -1.81967020e-02
#   1.84549302e-01  2.07055852e-01  8.31963792e-02  3.44798028e-01
#   1.23483501e-01  4.47896756e-02 -1.93566512e-02  1.03789844e-01
#  -3.55119914e-01 -2.42467616e-02  2.34606415e-01 -3.35651100e-01
#  -2.51844972e-01 -5.31178236e-01  1.03901170e-01  1.85205907e-01
#   4.95799780e-02 -5.89997172e-01  2.48919308e-01 -5.19744642e-02
#  -1.97772011e-01  3.63801062e-01  2.29746640e-01  8.19655210e-02
#   3.29178959e-01  2.54197359e-01 -3.89710903e-01  1.40177667e-01
#   1.60221055e-01  3.77872556e-01  2.15386838e-01 -1.80909663e-01
#  -3.14698890e-02  5.15435934e-01  1.47898391e-01 -5.18725276e-01
#  -1.33234337e-01 -5.14360368e-02 -1.83442291e-02  3.52605671e-01
#   9.66987014e-02 -2.87884176e-01  3.17581356e-01  1.97299853e-01
#  -1.54590728e-02  3.17798078e-01 -1.46943772e+00  1.50609493e-01
#   2.70542890e-01  1.04844235e-01  2.11775675e-01 -3.48359376e-01
#  -1.32428095e-01  7.19101071e-01 -1.67046309e-01  1.47598997e-01
#  -1.73075557e-01  1.61500841e-01  3.65818083e-01 -1.18561372e-01
#   4.23137322e-02  2.26231795e-02  4.42031622e-01 -9.45165753e-02
#  -7.14387968e-02  1.16841137e-01 -2.66112477e-01  8.25271845e-01
#  -3.68772358e-01 -1.87614456e-01 -3.09354901e-01 -9.18798894e-02
#   1.93366662e-01  2.21500278e-01  4.69242036e-02  2.58114010e-01
#   5.33982590e-02 -6.81025445e-01 -2.89496958e-01 -3.46364416e-02
#  -3.18901956e-01  1.82639509e-01  5.57760224e-02 -9.10042822e-02
#   3.97095352e-01  3.91766548e-01 -2.56759971e-01  4.26428974e-01
#   1.29239470e-01  6.01569191e-02  2.46100709e-01  5.40585160e-01
#  -4.04397041e-01  4.04119454e-02  1.52110606e-01 -1.68025404e-01
#  -1.00035310e-01 -6.03762195e-02 -3.36028814e-01  1.33158267e-01
#  -2.53972203e-01 -1.23461209e-01  9.08269361e-02 -4.73598465e-02
#  -2.35692799e-01  2.99748275e-02  6.22046232e-01  1.43693671e-01
#  -3.51839960e-01 -1.44252896e-01  6.36828765e-02 -6.77569926e-01
#  -9.07983035e-02 -2.59643018e-01 -3.94456565e-01  2.01388255e-01
#   9.10525501e-01 -6.86871260e-02 -3.87117982e-01 -2.17536017e-01
#  -6.11531019e-01  1.77900985e-01 -1.16122119e-01  4.25285965e-01
#   5.97190484e-02 -3.55264634e-01 -1.74384877e-01 -3.63369912e-01
#  -5.83240628e-01  1.83746383e-01 -1.93026975e-01 -1.20852724e-01
#  -1.54393271e-01  5.17187156e-02 -1.92041412e-01 -1.63835704e-01
#  -4.22174096e-01 -3.65840584e-01  1.94804832e-01  2.28431016e-01
#   5.15950918e-01  2.17326075e-01  4.65505123e-01 -3.73524390e-02
#  -1.22969843e-01  9.13921650e-03 -9.50702280e-02  4.79639858e-01
#   1.74349487e-01  3.70371640e-01  3.01432252e-01  1.09804675e-01
#   5.46779633e-01  1.53450385e-01 -2.50047058e-01 -1.09569490e-01
#  -8.49648118e-02 -3.92289925e-03  9.16773379e-02  1.95919666e-02
#   1.52712241e-01  1.52364865e-01  1.43537238e-01  2.32193340e-03
#   2.53721380e+00  4.14847523e-01  1.47755191e-01  1.67044565e-01
#   1.36828154e-01 -1.33964047e-01  2.32669953e-02  7.67828524e-02
#   2.64924252e-03  2.65702903e-01 -2.76707947e-01  7.32636750e-02
#   3.16064134e-02 -8.83178860e-02  1.75909847e-01  3.53541881e-01
#  -1.60114229e-01  2.35928148e-02 -3.59643430e-01 -4.50544357e-02
#  -6.23550177e-01  1.51597783e-01  3.43253225e-01 -2.56960243e-01
#  -1.21564165e-01  3.80490422e-01  2.76802868e-01 -1.66523680e-02
#  -2.53571749e-01 -6.62448257e-02 -8.94179866e-02  1.64268449e-01
#  -4.34209481e-02  2.68383056e-01 -1.51409939e-01 -1.80058144e-02
#   3.48051675e-02 -1.82719156e-01 -1.69398308e-01 -5.91729544e-02
#   1.08842365e-01 -6.75537050e-01  4.25572634e-01  1.47898823e-01
#  -1.94492742e-01  3.46409768e-01 -1.07246056e-01 -2.90335447e-01
#   1.90278485e-01 -2.36622058e-02 -1.25166103e-01 -9.21451002e-02
#  -2.04848170e-01  1.97418496e-01 -2.06552148e-02 -2.57952195e-02
#  -2.24390492e-01 -1.61348045e-01 -5.36998034e-01  2.05430344e-01
#  -7.50615373e-02  1.45637363e-01  2.88733482e-01 -5.03204204e-02
#  -3.44635025e-02 -1.62672669e-01 -2.44382054e-01  3.94463032e-01
#  -2.30462417e-01  3.72833051e-02 -2.20996648e-01 -1.57101765e-01
#   1.47108138e-01  2.87441134e-01  2.68133759e-01 -9.10302699e-02
#   1.60458356e-01 -9.26253870e-02 -7.27471039e-02 -2.90158868e+00
#  -6.77245343e-03  1.60161242e-01  3.93789411e-02  5.02293892e-02
#  -3.17779630e-02 -7.29813054e-03 -1.34499609e-01 -6.35144934e-02
#   3.43707465e-02  2.73368865e-01  2.43736103e-01  5.19050062e-01
#  -5.61365671e-02  1.46908045e-01  1.88210204e-01  9.67603177e-02
#  -5.44681370e-01 -2.35752866e-01  2.28894487e-01  3.07432801e-01
#   1.03554972e-01 -1.04970239e-01 -1.34179378e-02 -5.38719654e-01
#  -2.04169989e-01  3.56615305e-01 -1.98745131e-01  2.29325145e-02
#   5.09139240e-01 -5.03920484e-03  1.88126132e-01 -3.24201141e-03
#   1.41076073e-01 -2.31147870e-01 -1.38190622e-03  1.83277637e-01
#   9.00434479e-02 -1.76218674e-02  4.07240212e-01 -1.24698073e-01
#   4.47625071e-01 -9.06525180e-02  7.21431822e-02 -1.11959688e-01
#   1.55583993e-01  7.41910487e-02 -2.78677195e-01  1.17383279e-01
#  -3.81049991e-01 -1.95632935e-01  2.09218323e-01 -7.77197704e-02
#   1.76670074e-01  2.37423599e-01  2.55154073e-01  3.02082300e-01
#  -2.80949205e-01 -2.82798588e-01  1.06277145e-01 -2.83293009e-01
#   2.09085956e-01 -1.18154697e-01 -1.20384790e-01  3.69658589e-01
#  -1.99034601e-01 -2.70355880e-01  2.75926769e-01 -3.00511658e-01
#   2.19708890e-01 -9.79654305e-03 -8.37244764e-02 -2.71627549e-02
#   3.05337071e-01  3.31487395e-02  9.15090069e-02  2.37129658e-01
#  -4.56198677e-02  1.90166354e-01  3.94895494e-01 -1.95680827e-01
#  -4.54733133e-01 -2.05671430e-01  3.52176815e-01  4.92175110e-02
#  -7.52000761e+00 -6.46052182e-01 -2.78297991e-01 -3.92774455e-02
#   1.44291475e-01  6.28938451e-02  3.78451049e-01  1.17421718e-02
#   2.42446810e-01  9.66446102e-02  1.48052931e-01 -6.97466955e-02
#  -6.31359518e-02 -2.17742816e-01  4.32215333e-02  4.49418873e-01]
# <ipython-input-7-ecb8fe32c3ea>:25: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:278.)
#   X = torch.tensor(data['bert_embedding'].tolist(), dtype=torch.float32)

# %%
import torch.nn as nn
import torch.optim as optim

# RBM Class
class RBM(nn.Module):
    def __init__(self, visible_dim, hidden_dim):
        super(RBM, self).__init__()
        self.visible_dim = visible_dim
        self.hidden_dim = hidden_dim
        self.W = nn.Parameter(torch.randn(hidden_dim, visible_dim) * 0.1)
        self.h_bias = nn.Parameter(torch.zeros(hidden_dim))
        self.v_bias = nn.Parameter(torch.zeros(visible_dim))

    def sample_hidden(self, v):
        h_prob = torch.sigmoid(torch.matmul(v, self.W.t()) + self.h_bias)
        return h_prob, torch.bernoulli(h_prob)

    def sample_visible(self, h):
        v_prob = torch.sigmoid(torch.matmul(h, self.W) + self.v_bias)
        return v_prob, torch.bernoulli(v_prob)

    def forward(self, v):
        _, h = self.sample_hidden(v)
        return h

# DBN Class
class DBN(nn.Module):
    def __init__(self, layers):
        super(DBN, self).__init__()
        self.rbms = nn.ModuleList([
            RBM(layers[i], layers[i + 1]) for i in range(len(layers) - 1)
        ])

    def forward(self, x):
        for rbm in self.rbms:
            x, _ = rbm.sample_hidden(x)
        return x

# DBN Classifier with Dropout
class DBNClassifier(nn.Module):
    def __init__(self, dbn, output_dim, dropout_rate=0.5):
        super(DBNClassifier, self).__init__()
        self.dbn = dbn
        self.dropout = nn.Dropout(p=dropout_rate)  # Dropout Layer
        self.classifier = nn.Linear(dbn.rbms[-1].hidden_dim, output_dim)

    def forward(self, x):
        x = self.dbn(x)
        x = self.dropout(x)  # Apply Dropout
        x = self.classifier(x)
        return x

# Training RBM
def train_rbm(rbm, data, epochs, batch_size, learning_rate):
    optimizer = optim.SGD(rbm.parameters(), lr=learning_rate)
    criterion = nn.MSELoss()
    for epoch in range(epochs):
        for i in range(0, len(data), batch_size):
            batch = data[i:i + batch_size]
            batch = torch.tensor(batch, dtype=torch.float32)
            v_prob, v_sample = rbm.sample_visible(rbm.sample_hidden(batch)[1])
            loss = criterion(v_prob, batch)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

# Training DBN
def train_dbn(dbn, data, epochs_per_rbm, batch_size, learning_rate):
    input_data = data
    for rbm in dbn.rbms:
        train_rbm(rbm, input_data, epochs_per_rbm, batch_size=batch_size, learning_rate=learning_rate)
        input_data = rbm.forward(torch.tensor(input_data, dtype=torch.float32)).detach().numpy()

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score, classification_report
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

# %%
kf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
fold_accuracies = []
fold_precisions = []
fold_recalls = []
fold_f1_scores = []

for fold, (train_idx, val_idx) in enumerate(kf.split(X, y)):
    print(f"Processing Fold {fold + 1}...")
    X_train, X_val = X[train_idx], X[val_idx]
    y_train, y_val = y[train_idx], y[val_idx]

    dbn = DBN([X.shape[1], 128, 64])
    classifier = DBNClassifier(dbn, output_dim=len(torch.unique(y)), dropout_rate=0.5)

    train_dbn(dbn, X_train.numpy(), epochs_per_rbm=21, batch_size=127, learning_rate=0.001)

    classifier.eval()
    with torch.no_grad():
        y_val_pred = torch.argmax(classifier(X_val), dim=1)
        accuracy = accuracy_score(y_val.numpy(), y_val_pred.numpy())
        report = classification_report(y_val.numpy(), y_val_pred.numpy(), output_dict=True)

        fold_accuracies.append(accuracy)
        fold_precisions.append(report['weighted avg']['precision'])
        fold_recalls.append(report['weighted avg']['recall'])
        fold_f1_scores.append(report['weighted avg']['f1-score'])

        print(f"Fold {fold + 1} Accuracy: {accuracy:.4f}")

# Boxplot
metrics_df = pd.DataFrame({
    'Fold': list(range(1, 11)),
    'Accuracy': fold_accuracies,
    'Precision': fold_precisions,
    'Recall': fold_recalls,
    'F1-Score': fold_f1_scores
})

plt.figure(figsize=(12, 6))
sns.boxplot(data=metrics_df.melt(id_vars='Fold', var_name='Metric', value_name='Score'), x='Metric', y='Score')
plt.title("Box Plot of Evaluation Metrics Across Folds")
plt.grid(True)
plt.show()

# %%
# !pip install optuna
import optuna
# Out:
# Collecting optuna
#   Downloading optuna-4.1.0-py3-none-any.whl.metadata (16 kB)
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.14.0-py3-none-any.whl.metadata (7.4 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optuna) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.36)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0.2)
# Collecting Mako (from alembic>=1.5.0->optuna)
#   Downloading Mako-1.3.8-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.1.1)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna) (3.0.2)
# Downloading optuna-4.1.0-py3-none-any.whl (364 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 364.4/364.4 kB 6.6 MB/s eta 0:00:00
# Downloading alembic-1.14.0-py3-none-any.whl (233 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.5/233.5 kB 14.5 MB/s eta 0:00:00
# Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Downloading Mako-1.3.8-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 5.4 MB/s eta 0:00:00
# Installing collected packages: Mako, colorlog, alembic, optuna
# Successfully installed Mako-1.3.8 alembic-1.14.0 colorlog-6.9.0 optuna-4.1.0

# %%
# !pip install optuna
# Out:
# Collecting optuna
#   Downloading optuna-4.1.0-py3-none-any.whl.metadata (16 kB)
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.14.0-py3-none-any.whl.metadata (7.4 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optuna) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.36)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0.2)
# Collecting Mako (from alembic>=1.5.0->optuna)
#   Downloading Mako-1.3.8-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.1.1)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna) (3.0.2)
# Downloading optuna-4.1.0-py3-none-any.whl (364 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 364.4/364.4 kB 7.2 MB/s eta 0:00:00
# Downloading alembic-1.14.0-py3-none-any.whl (233 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.5/233.5 kB 15.5 MB/s eta 0:00:00
# Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Downloading Mako-1.3.8-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 5.6 MB/s eta 0:00:00
# Installing collected packages: Mako, colorlog, alembic, optuna
# Successfully installed Mako-1.3.8 alembic-1.14.0 colorlog-6.9.0 optuna-4.1.0

# %%
import optuna
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score

def objective(trial):
    # Sampling hyperparameter
    lr = trial.suggest_float('lr', 1e-5, 1e-1, log=True)
    batch_size = trial.suggest_int('batch_size', 16, 128)
    epoch = trial.suggest_int('epoch', 5, 50)
    epoch_per_rbm = trial.suggest_int('epoch_per_rbm', 5, 50)

    kf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
    fold_accuracies = []

    for train_idx, val_idx in kf.split(X, y):
        X_train, X_val = X[train_idx], X[val_idx]
        y_train, y_val = y[train_idx], y[val_idx]

        dbn = DBN([X.shape[1], 128, 64])
        classifier = DBNClassifier(dbn, output_dim=len(torch.unique(y)), dropout_rate=0.5)

        train_dbn(dbn, X_train.numpy(), epochs_per_rbm=epoch_per_rbm, batch_size=batch_size, learning_rate=lr)

        classifier.train()
        for _ in range(epoch):
            optimizer = optim.Adam(classifier.parameters(), lr=lr)
            for i in range(0, len(X_train), batch_size):
                batch_X = X_train[i:i + batch_size]
                batch_y = y_train[i:i + batch_size]
                optimizer.zero_grad()
                outputs = classifier(batch_X)
                loss = nn.CrossEntropyLoss()(outputs, batch_y)
                loss.backward()
                optimizer.step()

        classifier.eval()
        with torch.no_grad():
            y_val_pred = torch.argmax(classifier(X_val), dim=1)
            accuracy = accuracy_score(y_val.numpy(), y_val_pred.numpy())
            fold_accuracies.append(accuracy)

    return sum(fold_accuracies) / len(fold_accuracies)

study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=20)
print("Best hyperparameters:", study.best_params)
# Out:
# [I 2025-01-05 04:19:17,646] A new study created in memory with name: no-name-3a656164-a658-459e-a52a-f10d9d586c0b
# [I 2025-01-05 04:19:27,448] Trial 0 finished with value: 0.32407743496672714 and parameters: {'lr': 3.0066505944165845e-05, 'batch_size': 102, 'epoch': 31, 'epoch_per_rbm': 17}. Best is trial 0 with value: 0.32407743496672714.
# [I 2025-01-05 04:19:49,117] Trial 1 finished with value: 0.8762552934059287 and parameters: {'lr': 0.01275930569266937, 'batch_size': 40, 'epoch': 18, 'epoch_per_rbm': 46}. Best is trial 1 with value: 0.8762552934059287.
# [I 2025-01-05 04:20:12,910] Trial 2 finished with value: 0.9214761040532364 and parameters: {'lr': 0.005322765973882117, 'batch_size': 53, 'epoch': 40, 'epoch_per_rbm': 45}. Best is trial 2 with value: 0.9214761040532364.
# [I 2025-01-05 04:20:33,082] Trial 3 finished with value: 0.9268300060496069 and parameters: {'lr': 0.0008409135460026053, 'batch_size': 39, 'epoch': 46, 'epoch_per_rbm': 19}. Best is trial 3 with value: 0.9268300060496069.
# [I 2025-01-05 04:20:56,406] Trial 4 finished with value: 0.3469147005444646 and parameters: {'lr': 3.987667154339406e-05, 'batch_size': 52, 'epoch': 37, 'epoch_per_rbm': 48}. Best is trial 3 with value: 0.9268300060496069.
# [I 2025-01-05 04:21:00,769] Trial 5 finished with value: 0.675892316999395 and parameters: {'lr': 0.004231166982203035, 'batch_size': 112, 'epoch': 5, 'epoch_per_rbm': 15}. Best is trial 3 with value: 0.9268300060496069.
# [I 2025-01-05 04:21:20,895] Trial 6 finished with value: 0.8866908650937688 and parameters: {'lr': 0.0007337509318920385, 'batch_size': 71, 'epoch': 39, 'epoch_per_rbm': 44}. Best is trial 3 with value: 0.9268300060496069.
# [I 2025-01-05 04:21:50,385] Trial 7 finished with value: 0.7055656382335149 and parameters: {'lr': 0.00019163247722306438, 'batch_size': 29, 'epoch': 34, 'epoch_per_rbm': 41}. Best is trial 3 with value: 0.9268300060496069.
# [I 2025-01-05 04:22:07,899] Trial 8 finished with value: 0.28012704174228675 and parameters: {'lr': 1.2227736492526082e-05, 'batch_size': 74, 'epoch': 40, 'epoch_per_rbm': 38}. Best is trial 3 with value: 0.9268300060496069.
# [I 2025-01-05 04:22:16,345] Trial 9 finished with value: 0.3137326073805203 and parameters: {'lr': 6.400195474839667e-05, 'batch_size': 117, 'epoch': 15, 'epoch_per_rbm': 26}. Best is trial 3 with value: 0.9268300060496069.
# [I 2025-01-05 04:22:50,012] Trial 10 finished with value: 0.25623109497882635 and parameters: {'lr': 0.08639968916535011, 'batch_size': 16, 'epoch': 50, 'epoch_per_rbm': 5}. Best is trial 3 with value: 0.9268300060496069.
# [I 2025-01-05 04:23:09,919] Trial 11 finished with value: 0.9442226255293406 and parameters: {'lr': 0.0026964986618704975, 'batch_size': 59, 'epoch': 50, 'epoch_per_rbm': 33}. Best is trial 11 with value: 0.9442226255293406.
# [I 2025-01-05 04:23:26,629] Trial 12 finished with value: 0.867513611615245 and parameters: {'lr': 0.0005768352183510334, 'batch_size': 77, 'epoch': 48, 'epoch_per_rbm': 31}. Best is trial 11 with value: 0.9442226255293406.
# [I 2025-01-05 04:23:43,955] Trial 13 finished with value: 0.9286146400483968 and parameters: {'lr': 0.0020939458795525196, 'batch_size': 54, 'epoch': 46, 'epoch_per_rbm': 24}. Best is trial 11 with value: 0.9442226255293406.
# [I 2025-01-05 04:23:55,824] Trial 14 finished with value: 0.9147005444646098 and parameters: {'lr': 0.020605492913677817, 'batch_size': 92, 'epoch': 25, 'epoch_per_rbm': 32}. Best is trial 11 with value: 0.9442226255293406.
# [I 2025-01-05 04:24:11,898] Trial 15 finished with value: 0.9476709013914096 and parameters: {'lr': 0.003223171362908692, 'batch_size': 61, 'epoch': 44, 'epoch_per_rbm': 24}. Best is trial 15 with value: 0.9476709013914096.
# [I 2025-01-05 04:24:26,744] Trial 16 finished with value: 0.8467937084089533 and parameters: {'lr': 0.026769226773018087, 'batch_size': 67, 'epoch': 26, 'epoch_per_rbm': 35}. Best is trial 15 with value: 0.9476709013914096.
# [I 2025-01-05 04:24:35,814] Trial 17 finished with value: 0.6691167574107683 and parameters: {'lr': 0.00021984284419745027, 'batch_size': 90, 'epoch': 44, 'epoch_per_rbm': 10}. Best is trial 15 with value: 0.9476709013914096.
# [I 2025-01-05 04:24:52,107] Trial 18 finished with value: 0.9546884452510588 and parameters: {'lr': 0.0019964109815428124, 'batch_size': 62, 'epoch': 50, 'epoch_per_rbm': 22}. Best is trial 18 with value: 0.9546884452510588.
# [I 2025-01-05 04:25:04,792] Trial 19 finished with value: 0.9268602540834847 and parameters: {'lr': 0.009978254738497871, 'batch_size': 87, 'epoch': 43, 'epoch_per_rbm': 24}. Best is trial 18 with value: 0.9546884452510588.
# Best hyperparameters: {'lr': 0.0019964109815428124, 'batch_size': 62, 'epoch': 50, 'epoch_per_rbm': 22}

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Gunakan hyperparameter terbaik dari Bayesian Optimization
best_params = study.best_params
print("Hyperparameter Optimal:", best_params)

kf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)

fold_accuracies = []
all_true_labels = []
all_predicted_labels = []

# Loop untuk setiap fold
for fold, (train_idx, val_idx) in enumerate(kf.split(X, y)):
    print(f"Processing Fold {fold + 1}...")

    # Split data untuk fold ini
    X_train, X_val = X[train_idx], X[val_idx]
    y_train, y_val = y[train_idx], y[val_idx]

    # Inisialisasi model
    dbn = DBN([X.shape[1], 128, 64])
    classifier = DBNClassifier(dbn, output_dim=len(torch.unique(y)), dropout_rate=0.5)

    # Pretrain DBN
    train_dbn(dbn, X_train.numpy(), epochs_per_rbm=best_params['epoch_per_rbm'],
              batch_size=best_params['batch_size'], learning_rate=best_params['lr'])

    # Fine-tune DBNClassifier
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(classifier.parameters(), lr=best_params['lr'])
    for _ in range(best_params['epoch']):
        classifier.train()
        for i in range(0, len(X_train), best_params['batch_size']):
            batch_X = X_train[i:i + best_params['batch_size']]
            batch_y = y_train[i:i + best_params['batch_size']]
            optimizer.zero_grad()
            outputs = classifier(batch_X)
            loss = criterion(outputs, batch_y)
            loss.backward()
            optimizer.step()

    # Evaluasi model pada validation set
    classifier.eval()
    with torch.no_grad():
        y_val_pred = torch.argmax(classifier(X_val), dim=1).numpy()
        fold_accuracy = accuracy_score(y_val.numpy(), y_val_pred)
        fold_accuracies.append(fold_accuracy)

        # Simpan hasil prediksi dan label asli untuk confusion matrix
        all_true_labels.extend(y_val.numpy())
        all_predicted_labels.extend(y_val_pred)

    print(f"Fold {fold + 1} Accuracy: {fold_accuracy:.4f}")

# Rata-rata akurasi
avg_accuracy = sum(fold_accuracies) / len(fold_accuracies)
print(f"\nRata-rata Akurasi Cross-Validation: {avg_accuracy:.4f}")

# Evaluasi keseluruhan
print("\nClassification Report (All Folds):")
print(classification_report(all_true_labels, all_predicted_labels, target_names=['O', 'PE', 'SE', 'US']))

# Confusion Matrix
conf_matrix = confusion_matrix(all_true_labels, all_predicted_labels)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['O', 'PE', 'SE', 'US'], yticklabels=['O', 'PE', 'SE', 'US'])
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix Heatmap (All Folds)")
plt.show()
# Out:
# Hyperparameter Optimal: {'lr': 0.0019964109815428124, 'batch_size': 62, 'epoch': 50, 'epoch_per_rbm': 22}
# Processing Fold 1...
# Fold 1 Accuracy: 0.9655
# Processing Fold 2...
# Fold 2 Accuracy: 0.9655
# Processing Fold 3...
# Fold 3 Accuracy: 0.9483
# Processing Fold 4...
# Fold 4 Accuracy: 0.9655
# Processing Fold 5...
# Fold 5 Accuracy: 1.0000
# Processing Fold 6...
# Fold 6 Accuracy: 0.8947
# Processing Fold 7...
# Fold 7 Accuracy: 0.8947
# Processing Fold 8...
# Fold 8 Accuracy: 0.9649
# Processing Fold 9...
# Fold 9 Accuracy: 0.9474
# Processing Fold 10...
# Fold 10 Accuracy: 0.9649
#
# Rata-rata Akurasi Cross-Validation: 0.9511
#
# Classification Report (All Folds):
#               precision    recall  f1-score   support
#
#            O       0.95      0.95      0.95       130
#           PE       0.94      0.93      0.94       128
#           SE       0.95      0.95      0.95       154
#           US       0.96      0.97      0.96       162
#
#     accuracy                           0.95       574
#    macro avg       0.95      0.95      0.95       574
# weighted avg       0.95      0.95      0.95       574

# %%
train_losses = []
val_losses = []
train_accuracies = []
val_accuracies = []

for fold, (train_idx, val_idx) in enumerate(kf.split(X, y)):
    print(f"Processing Fold {fold + 1}...")

    X_train, X_val = X[train_idx], X[val_idx]
    y_train, y_val = y[train_idx], y[val_idx]

    dbn = DBN([X.shape[1], 128, 64])
    classifier = DBNClassifier(dbn, output_dim=len(torch.unique(y)), dropout_rate=0.5)

    train_dbn(dbn, X_train.numpy(), epochs_per_rbm=best_params['epoch_per_rbm'],
              batch_size=best_params['batch_size'], learning_rate=best_params['lr'])

    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(classifier.parameters(), lr=best_params['lr'])

    fold_train_losses = []
    fold_val_losses = []
    fold_train_accuracies = []
    fold_val_accuracies = []

    for epoch in range(best_params['epoch']):
        classifier.train()
        epoch_train_loss = 0
        correct_train = 0

        for i in range(0, len(X_train), best_params['batch_size']):
            batch_X = X_train[i:i + best_params['batch_size']]
            batch_y = y_train[i:i + best_params['batch_size']]

            optimizer.zero_grad()
            outputs = classifier(batch_X)
            loss = criterion(outputs, batch_y)
            loss.backward()
            optimizer.step()

            epoch_train_loss += loss.item()
            correct_train += (torch.argmax(outputs, dim=1) == batch_y).sum().item()

        epoch_train_loss /= len(X_train)
        epoch_train_accuracy = correct_train / len(X_train)
        fold_train_losses.append(epoch_train_loss)
        fold_train_accuracies.append(epoch_train_accuracy)

        classifier.eval()
        epoch_val_loss = 0
        correct_val = 0

        with torch.no_grad():
            for i in range(0, len(X_val), best_params['batch_size']):
                batch_X = X_val[i:i + best_params['batch_size']]
                batch_y = y_val[i:i + best_params['batch_size']]
                outputs = classifier(batch_X)
                loss = criterion(outputs, batch_y)
                epoch_val_loss += loss.item()
                correct_val += (torch.argmax(outputs, dim=1) == batch_y).sum().item()

        epoch_val_loss /= len(X_val)
        epoch_val_accuracy = correct_val / len(X_val)
        fold_val_losses.append(epoch_val_loss)
        fold_val_accuracies.append(epoch_val_accuracy)

        print(f"Epoch {epoch + 1}/{best_params['epoch']} - Train Loss: {epoch_train_loss:.4f}, "
              f"Train Accuracy: {epoch_train_accuracy:.4f}, Val Loss: {epoch_val_loss:.4f}, "
              f"Val Accuracy: {epoch_val_accuracy:.4f}")

    train_losses.append(fold_train_losses)
    val_losses.append(fold_val_losses)
    train_accuracies.append(fold_train_accuracies)
    val_accuracies.append(fold_val_accuracies)
# Out:
# Processing Fold 1...
# Epoch 1/50 - Train Loss: 0.0248, Train Accuracy: 0.2849, Val Loss: 0.0234, Val Accuracy: 0.2759
# Epoch 2/50 - Train Loss: 0.0240, Train Accuracy: 0.3062, Val Loss: 0.0228, Val Accuracy: 0.4655
# Epoch 3/50 - Train Loss: 0.0232, Train Accuracy: 0.3682, Val Loss: 0.0221, Val Accuracy: 0.5000
# Epoch 4/50 - Train Loss: 0.0222, Train Accuracy: 0.4535, Val Loss: 0.0211, Val Accuracy: 0.5862
# Epoch 5/50 - Train Loss: 0.0209, Train Accuracy: 0.5465, Val Loss: 0.0196, Val Accuracy: 0.6379
# Epoch 6/50 - Train Loss: 0.0193, Train Accuracy: 0.5678, Val Loss: 0.0180, Val Accuracy: 0.7069
# Epoch 7/50 - Train Loss: 0.0175, Train Accuracy: 0.6628, Val Loss: 0.0162, Val Accuracy: 0.7586
# Epoch 8/50 - Train Loss: 0.0155, Train Accuracy: 0.7306, Val Loss: 0.0144, Val Accuracy: 0.7759
# Epoch 9/50 - Train Loss: 0.0136, Train Accuracy: 0.7810, Val Loss: 0.0126, Val Accuracy: 0.8276
# Epoch 10/50 - Train Loss: 0.0124, Train Accuracy: 0.7849, Val Loss: 0.0110, Val Accuracy: 0.8793
# Epoch 11/50 - Train Loss: 0.0105, Train Accuracy: 0.8372, Val Loss: 0.0096, Val Accuracy: 0.8966
# Epoch 12/50 - Train Loss: 0.0092, Train Accuracy: 0.8895, Val Loss: 0.0084, Val Accuracy: 0.8966
# Epoch 13/50 - Train Loss: 0.0081, Train Accuracy: 0.8992, Val Loss: 0.0074, Val Accuracy: 0.9310
# Epoch 14/50 - Train Loss: 0.0068, Train Accuracy: 0.9070, Val Loss: 0.0065, Val Accuracy: 0.9483
# Epoch 15/50 - Train Loss: 0.0059, Train Accuracy: 0.9225, Val Loss: 0.0058, Val Accuracy: 0.9483
# Epoch 16/50 - Train Loss: 0.0053, Train Accuracy: 0.9322, Val Loss: 0.0051, Val Accuracy: 0.9483
# Epoch 17/50 - Train Loss: 0.0048, Train Accuracy: 0.9419, Val Loss: 0.0049, Val Accuracy: 0.9310
# Epoch 18/50 - Train Loss: 0.0043, Train Accuracy: 0.9554, Val Loss: 0.0044, Val Accuracy: 0.9483
# Epoch 19/50 - Train Loss: 0.0038, Train Accuracy: 0.9709, Val Loss: 0.0038, Val Accuracy: 0.9655
# Epoch 20/50 - Train Loss: 0.0033, Train Accuracy: 0.9690, Val Loss: 0.0036, Val Accuracy: 0.9655
# Epoch 21/50 - Train Loss: 0.0030, Train Accuracy: 0.9767, Val Loss: 0.0034, Val Accuracy: 0.9655
# Epoch 22/50 - Train Loss: 0.0028, Train Accuracy: 0.9729, Val Loss: 0.0031, Val Accuracy: 0.9655
# Epoch 23/50 - Train Loss: 0.0027, Train Accuracy: 0.9787, Val Loss: 0.0034, Val Accuracy: 0.9310
# Epoch 24/50 - Train Loss: 0.0021, Train Accuracy: 0.9845, Val Loss: 0.0030, Val Accuracy: 0.9655
# Epoch 25/50 - Train Loss: 0.0020, Train Accuracy: 0.9845, Val Loss: 0.0033, Val Accuracy: 0.9310
# Epoch 26/50 - Train Loss: 0.0019, Train Accuracy: 0.9826, Val Loss: 0.0027, Val Accuracy: 0.9655
# Epoch 27/50 - Train Loss: 0.0018, Train Accuracy: 0.9884, Val Loss: 0.0034, Val Accuracy: 0.9138
# Epoch 28/50 - Train Loss: 0.0018, Train Accuracy: 0.9787, Val Loss: 0.0026, Val Accuracy: 0.9655
# Epoch 29/50 - Train Loss: 0.0014, Train Accuracy: 0.9922, Val Loss: 0.0028, Val Accuracy: 0.9483
# Epoch 30/50 - Train Loss: 0.0013, Train Accuracy: 0.9922, Val Loss: 0.0024, Val Accuracy: 0.9655
# Epoch 31/50 - Train Loss: 0.0013, Train Accuracy: 0.9942, Val Loss: 0.0026, Val Accuracy: 0.9483
# Epoch 32/50 - Train Loss: 0.0010, Train Accuracy: 1.0000, Val Loss: 0.0022, Val Accuracy: 0.9655
# Epoch 33/50 - Train Loss: 0.0010, Train Accuracy: 0.9942, Val Loss: 0.0023, Val Accuracy: 0.9483
# Epoch 34/50 - Train Loss: 0.0010, Train Accuracy: 0.9942, Val Loss: 0.0022, Val Accuracy: 0.9655
# Epoch 35/50 - Train Loss: 0.0011, Train Accuracy: 0.9922, Val Loss: 0.0024, Val Accuracy: 0.9483
# Epoch 36/50 - Train Loss: 0.0008, Train Accuracy: 1.0000, Val Loss: 0.0022, Val Accuracy: 0.9655
# Epoch 37/50 - Train Loss: 0.0009, Train Accuracy: 0.9961, Val Loss: 0.0025, Val Accuracy: 0.9483
# Epoch 38/50 - Train Loss: 0.0008, Train Accuracy: 1.0000, Val Loss: 0.0021, Val Accuracy: 0.9655
# Epoch 39/50 - Train Loss: 0.0007, Train Accuracy: 0.9981, Val Loss: 0.0022, Val Accuracy: 0.9655
# Epoch 40/50 - Train Loss: 0.0007, Train Accuracy: 0.9981, Val Loss: 0.0020, Val Accuracy: 0.9655
# Epoch 41/50 - Train Loss: 0.0007, Train Accuracy: 0.9961, Val Loss: 0.0020, Val Accuracy: 0.9655
# Epoch 42/50 - Train Loss: 0.0005, Train Accuracy: 1.0000, Val Loss: 0.0019, Val Accuracy: 0.9655
# Epoch 43/50 - Train Loss: 0.0006, Train Accuracy: 0.9961, Val Loss: 0.0020, Val Accuracy: 0.9655
# Epoch 44/50 - Train Loss: 0.0005, Train Accuracy: 0.9981, Val Loss: 0.0018, Val Accuracy: 0.9655
# Epoch 45/50 - Train Loss: 0.0006, Train Accuracy: 0.9981, Val Loss: 0.0021, Val Accuracy: 0.9483
# Epoch 46/50 - Train Loss: 0.0005, Train Accuracy: 1.0000, Val Loss: 0.0018, Val Accuracy: 0.9655
# Epoch 47/50 - Train Loss: 0.0005, Train Accuracy: 0.9981, Val Loss: 0.0018, Val Accuracy: 0.9655
# Epoch 48/50 - Train Loss: 0.0005, Train Accuracy: 0.9961, Val Loss: 0.0017, Val Accuracy: 0.9655
# Epoch 49/50 - Train Loss: 0.0004, Train Accuracy: 1.0000, Val Loss: 0.0016, Val Accuracy: 0.9655
# Epoch 50/50 - Train Loss: 0.0004, Train Accuracy: 1.0000, Val Loss: 0.0017, Val Accuracy: 0.9655
# Processing Fold 2...
# Epoch 1/50 - Train Loss: 0.0249, Train Accuracy: 0.2384, Val Loss: 0.0235, Val Accuracy: 0.3276
# Epoch 2/50 - Train Loss: 0.0239, Train Accuracy: 0.3314, Val Loss: 0.0229, Val Accuracy: 0.3966
# Epoch 3/50 - Train Loss: 0.0233, Train Accuracy: 0.3411, Val Loss: 0.0222, Val Accuracy: 0.6552
# Epoch 4/50 - Train Loss: 0.0223, Train Accuracy: 0.4264, Val Loss: 0.0211, Val Accuracy: 0.6034
# Epoch 5/50 - Train Loss: 0.0208, Train Accuracy: 0.5349, Val Loss: 0.0198, Val Accuracy: 0.6897
# Epoch 6/50 - Train Loss: 0.0193, Train Accuracy: 0.5698, Val Loss: 0.0182, Val Accuracy: 0.7241
# Epoch 7/50 - Train Loss: 0.0176, Train Accuracy: 0.6686, Val Loss: 0.0164, Val Accuracy: 0.7241
# Epoch 8/50 - Train Loss: 0.0155, Train Accuracy: 0.7306, Val Loss: 0.0147, Val Accuracy: 0.7759
# Epoch 9/50 - Train Loss: 0.0143, Train Accuracy: 0.7209, Val Loss: 0.0130, Val Accuracy: 0.8276
# Epoch 10/50 - Train Loss: 0.0127, Train Accuracy: 0.7636, Val Loss: 0.0116, Val Accuracy: 0.8621
# Epoch 11/50 - Train Loss: 0.0108, Train Accuracy: 0.8333, Val Loss: 0.0100, Val Accuracy: 0.8793
# Epoch 12/50 - Train Loss: 0.0095, Train Accuracy: 0.8605, Val Loss: 0.0090, Val Accuracy: 0.8966
# Epoch 13/50 - Train Loss: 0.0079, Train Accuracy: 0.9050, Val Loss: 0.0080, Val Accuracy: 0.9138
# Epoch 14/50 - Train Loss: 0.0071, Train Accuracy: 0.9050, Val Loss: 0.0071, Val Accuracy: 0.9138
# Epoch 15/50 - Train Loss: 0.0062, Train Accuracy: 0.9186, Val Loss: 0.0064, Val Accuracy: 0.9138
# Epoch 16/50 - Train Loss: 0.0056, Train Accuracy: 0.9322, Val Loss: 0.0060, Val Accuracy: 0.9138
# Epoch 17/50 - Train Loss: 0.0049, Train Accuracy: 0.9419, Val Loss: 0.0052, Val Accuracy: 0.9310
# Epoch 18/50 - Train Loss: 0.0043, Train Accuracy: 0.9419, Val Loss: 0.0048, Val Accuracy: 0.9138
# Epoch 19/50 - Train Loss: 0.0040, Train Accuracy: 0.9496, Val Loss: 0.0047, Val Accuracy: 0.9310
# Epoch 20/50 - Train Loss: 0.0034, Train Accuracy: 0.9690, Val Loss: 0.0041, Val Accuracy: 0.9138
# Epoch 21/50 - Train Loss: 0.0031, Train Accuracy: 0.9690, Val Loss: 0.0037, Val Accuracy: 0.9310
# Epoch 22/50 - Train Loss: 0.0028, Train Accuracy: 0.9767, Val Loss: 0.0035, Val Accuracy: 0.9310
# Epoch 23/50 - Train Loss: 0.0026, Train Accuracy: 0.9845, Val Loss: 0.0032, Val Accuracy: 0.9483
# Epoch 24/50 - Train Loss: 0.0023, Train Accuracy: 0.9787, Val Loss: 0.0034, Val Accuracy: 0.9483
# Epoch 25/50 - Train Loss: 0.0023, Train Accuracy: 0.9806, Val Loss: 0.0030, Val Accuracy: 0.9655
# Epoch 26/50 - Train Loss: 0.0021, Train Accuracy: 0.9806, Val Loss: 0.0029, Val Accuracy: 0.9483
# Epoch 27/50 - Train Loss: 0.0020, Train Accuracy: 0.9845, Val Loss: 0.0027, Val Accuracy: 0.9655
# Epoch 28/50 - Train Loss: 0.0018, Train Accuracy: 0.9864, Val Loss: 0.0026, Val Accuracy: 0.9655
# Epoch 29/50 - Train Loss: 0.0016, Train Accuracy: 0.9884, Val Loss: 0.0026, Val Accuracy: 0.9655
# Epoch 30/50 - Train Loss: 0.0011, Train Accuracy: 0.9961, Val Loss: 0.0026, Val Accuracy: 0.9655
# Epoch 31/50 - Train Loss: 0.0014, Train Accuracy: 0.9826, Val Loss: 0.0024, Val Accuracy: 0.9655
# Epoch 32/50 - Train Loss: 0.0014, Train Accuracy: 0.9864, Val Loss: 0.0024, Val Accuracy: 0.9655
# Epoch 33/50 - Train Loss: 0.0011, Train Accuracy: 0.9903, Val Loss: 0.0024, Val Accuracy: 0.9655
# Epoch 34/50 - Train Loss: 0.0012, Train Accuracy: 0.9942, Val Loss: 0.0023, Val Accuracy: 0.9655
# Epoch 35/50 - Train Loss: 0.0011, Train Accuracy: 0.9922, Val Loss: 0.0022, Val Accuracy: 0.9655
# Epoch 36/50 - Train Loss: 0.0011, Train Accuracy: 0.9903, Val Loss: 0.0021, Val Accuracy: 0.9655
# Epoch 37/50 - Train Loss: 0.0010, Train Accuracy: 0.9942, Val Loss: 0.0021, Val Accuracy: 0.9655
# Epoch 38/50 - Train Loss: 0.0008, Train Accuracy: 0.9961, Val Loss: 0.0021, Val Accuracy: 0.9655
# Epoch 39/50 - Train Loss: 0.0008, Train Accuracy: 0.9961, Val Loss: 0.0020, Val Accuracy: 0.9655
# Epoch 40/50 - Train Loss: 0.0009, Train Accuracy: 0.9922, Val Loss: 0.0021, Val Accuracy: 0.9655
# Epoch 41/50 - Train Loss: 0.0008, Train Accuracy: 0.9942, Val Loss: 0.0020, Val Accuracy: 0.9655
# Epoch 42/50 - Train Loss: 0.0008, Train Accuracy: 0.9942, Val Loss: 0.0019, Val Accuracy: 0.9655
# Epoch 43/50 - Train Loss: 0.0006, Train Accuracy: 0.9981, Val Loss: 0.0018, Val Accuracy: 0.9655
# Epoch 44/50 - Train Loss: 0.0007, Train Accuracy: 0.9961, Val Loss: 0.0018, Val Accuracy: 0.9655
# Epoch 45/50 - Train Loss: 0.0007, Train Accuracy: 0.9942, Val Loss: 0.0017, Val Accuracy: 0.9655
# Epoch 46/50 - Train Loss: 0.0006, Train Accuracy: 0.9981, Val Loss: 0.0017, Val Accuracy: 0.9655
# Epoch 47/50 - Train Loss: 0.0006, Train Accuracy: 0.9942, Val Loss: 0.0017, Val Accuracy: 0.9655
# Epoch 48/50 - Train Loss: 0.0005, Train Accuracy: 1.0000, Val Loss: 0.0019, Val Accuracy: 0.9655
# Epoch 49/50 - Train Loss: 0.0005, Train Accuracy: 0.9981, Val Loss: 0.0017, Val Accuracy: 0.9655
# Epoch 50/50 - Train Loss: 0.0004, Train Accuracy: 0.9981, Val Loss: 0.0021, Val Accuracy: 0.9483
# Processing Fold 3...
# Epoch 1/50 - Train Loss: 0.0245, Train Accuracy: 0.2539, Val Loss: 0.0235, Val Accuracy: 0.2759
# Epoch 2/50 - Train Loss: 0.0236, Train Accuracy: 0.3295, Val Loss: 0.0229, Val Accuracy: 0.4138
# Epoch 3/50 - Train Loss: 0.0233, Train Accuracy: 0.3469, Val Loss: 0.0222, Val Accuracy: 0.6034
# Epoch 4/50 - Train Loss: 0.0224, Train Accuracy: 0.4322, Val Loss: 0.0212, Val Accuracy: 0.6379
# Epoch 5/50 - Train Loss: 0.0208, Train Accuracy: 0.5349, Val Loss: 0.0199, Val Accuracy: 0.6724
# Epoch 6/50 - Train Loss: 0.0192, Train Accuracy: 0.5872, Val Loss: 0.0184, Val Accuracy: 0.7069
# Epoch 7/50 - Train Loss: 0.0178, Train Accuracy: 0.6802, Val Loss: 0.0169, Val Accuracy: 0.7241
# Epoch 8/50 - Train Loss: 0.0157, Train Accuracy: 0.6938, Val Loss: 0.0154, Val Accuracy: 0.7586
# Epoch 9/50 - Train Loss: 0.0140, Train Accuracy: 0.7481, Val Loss: 0.0137, Val Accuracy: 0.7586
# Epoch 10/50 - Train Loss: 0.0127, Train Accuracy: 0.7965, Val Loss: 0.0123, Val Accuracy: 0.8103
# Epoch 11/50 - Train Loss: 0.0107, Train Accuracy: 0.8372, Val Loss: 0.0109, Val Accuracy: 0.8448
# Epoch 12/50 - Train Loss: 0.0098, Train Accuracy: 0.8469, Val Loss: 0.0097, Val Accuracy: 0.8448
# Epoch 13/50 - Train Loss: 0.0086, Train Accuracy: 0.8740, Val Loss: 0.0085, Val Accuracy: 0.8621
# Epoch 14/50 - Train Loss: 0.0073, Train Accuracy: 0.8992, Val Loss: 0.0074, Val Accuracy: 0.8966
# Epoch 15/50 - Train Loss: 0.0062, Train Accuracy: 0.9302, Val Loss: 0.0067, Val Accuracy: 0.9310
# Epoch 16/50 - Train Loss: 0.0057, Train Accuracy: 0.9225, Val Loss: 0.0059, Val Accuracy: 0.9310
# Epoch 17/50 - Train Loss: 0.0047, Train Accuracy: 0.9438, Val Loss: 0.0053, Val Accuracy: 0.9310
# Epoch 18/50 - Train Loss: 0.0046, Train Accuracy: 0.9574, Val Loss: 0.0049, Val Accuracy: 0.9483
# Epoch 19/50 - Train Loss: 0.0039, Train Accuracy: 0.9593, Val Loss: 0.0046, Val Accuracy: 0.9138
# Epoch 20/50 - Train Loss: 0.0033, Train Accuracy: 0.9748, Val Loss: 0.0043, Val Accuracy: 0.9655
# Epoch 21/50 - Train Loss: 0.0029, Train Accuracy: 0.9748, Val Loss: 0.0039, Val Accuracy: 0.9655
# Epoch 22/50 - Train Loss: 0.0030, Train Accuracy: 0.9671, Val Loss: 0.0037, Val Accuracy: 0.9655
# Epoch 23/50 - Train Loss: 0.0024, Train Accuracy: 0.9748, Val Loss: 0.0036, Val Accuracy: 0.9655
# Epoch 24/50 - Train Loss: 0.0026, Train Accuracy: 0.9787, Val Loss: 0.0036, Val Accuracy: 0.9483
# Epoch 25/50 - Train Loss: 0.0020, Train Accuracy: 0.9806, Val Loss: 0.0033, Val Accuracy: 0.9655
# Epoch 26/50 - Train Loss: 0.0019, Train Accuracy: 0.9864, Val Loss: 0.0033, Val Accuracy: 0.9655
# Epoch 27/50 - Train Loss: 0.0018, Train Accuracy: 0.9806, Val Loss: 0.0034, Val Accuracy: 0.9483
# Epoch 28/50 - Train Loss: 0.0015, Train Accuracy: 0.9884, Val Loss: 0.0030, Val Accuracy: 0.9655
# Epoch 29/50 - Train Loss: 0.0018, Train Accuracy: 0.9826, Val Loss: 0.0031, Val Accuracy: 0.9483
# Epoch 30/50 - Train Loss: 0.0014, Train Accuracy: 0.9845, Val Loss: 0.0029, Val Accuracy: 0.9655
# Epoch 31/50 - Train Loss: 0.0013, Train Accuracy: 0.9903, Val Loss: 0.0030, Val Accuracy: 0.9483
# Epoch 32/50 - Train Loss: 0.0012, Train Accuracy: 0.9922, Val Loss: 0.0028, Val Accuracy: 0.9655
# Epoch 33/50 - Train Loss: 0.0014, Train Accuracy: 0.9884, Val Loss: 0.0033, Val Accuracy: 0.9483
# Epoch 34/50 - Train Loss: 0.0011, Train Accuracy: 0.9922, Val Loss: 0.0027, Val Accuracy: 0.9655
# Epoch 35/50 - Train Loss: 0.0009, Train Accuracy: 0.9942, Val Loss: 0.0033, Val Accuracy: 0.9483
# Epoch 36/50 - Train Loss: 0.0009, Train Accuracy: 0.9961, Val Loss: 0.0027, Val Accuracy: 0.9655
# Epoch 37/50 - Train Loss: 0.0009, Train Accuracy: 0.9961, Val Loss: 0.0033, Val Accuracy: 0.9483
# Epoch 38/50 - Train Loss: 0.0008, Train Accuracy: 0.9942, Val Loss: 0.0025, Val Accuracy: 0.9655
# Epoch 39/50 - Train Loss: 0.0009, Train Accuracy: 0.9961, Val Loss: 0.0030, Val Accuracy: 0.9483
# Epoch 40/50 - Train Loss: 0.0007, Train Accuracy: 0.9922, Val Loss: 0.0025, Val Accuracy: 0.9655
# Epoch 41/50 - Train Loss: 0.0008, Train Accuracy: 0.9981, Val Loss: 0.0028, Val Accuracy: 0.9310
# Epoch 42/50 - Train Loss: 0.0006, Train Accuracy: 1.0000, Val Loss: 0.0026, Val Accuracy: 0.9655
# Epoch 43/50 - Train Loss: 0.0005, Train Accuracy: 1.0000, Val Loss: 0.0027, Val Accuracy: 0.9483
# Epoch 44/50 - Train Loss: 0.0006, Train Accuracy: 0.9981, Val Loss: 0.0026, Val Accuracy: 0.9655
# Epoch 45/50 - Train Loss: 0.0005, Train Accuracy: 1.0000, Val Loss: 0.0027, Val Accuracy: 0.9655
# Epoch 46/50 - Train Loss: 0.0006, Train Accuracy: 0.9961, Val Loss: 0.0027, Val Accuracy: 0.9483
# Epoch 47/50 - Train Loss: 0.0004, Train Accuracy: 1.0000, Val Loss: 0.0027, Val Accuracy: 0.9483
# Epoch 48/50 - Train Loss: 0.0005, Train Accuracy: 0.9981, Val Loss: 0.0027, Val Accuracy: 0.9483
# Epoch 49/50 - Train Loss: 0.0004, Train Accuracy: 1.0000, Val Loss: 0.0025, Val Accuracy: 0.9655
# Epoch 50/50 - Train Loss: 0.0004, Train Accuracy: 0.9981, Val Loss: 0.0024, Val Accuracy: 0.9655
# Processing Fold 4...
# Epoch 1/50 - Train Loss: 0.0243, Train Accuracy: 0.2810, Val Loss: 0.0233, Val Accuracy: 0.3621
# Epoch 2/50 - Train Loss: 0.0235, Train Accuracy: 0.3372, Val Loss: 0.0227, Val Accuracy: 0.4655
# Epoch 3/50 - Train Loss: 0.0227, Train Accuracy: 0.4341, Val Loss: 0.0219, Val Accuracy: 0.5345
# Epoch 4/50 - Train Loss: 0.0216, Train Accuracy: 0.4845, Val Loss: 0.0208, Val Accuracy: 0.5862
# Epoch 5/50 - Train Loss: 0.0203, Train Accuracy: 0.5756, Val Loss: 0.0195, Val Accuracy: 0.5690
# Epoch 6/50 - Train Loss: 0.0191, Train Accuracy: 0.6202, Val Loss: 0.0181, Val Accuracy: 0.5862
# Epoch 7/50 - Train Loss: 0.0169, Train Accuracy: 0.6628, Val Loss: 0.0165, Val Accuracy: 0.6552
# Epoch 8/50 - Train Loss: 0.0155, Train Accuracy: 0.7248, Val Loss: 0.0150, Val Accuracy: 0.6897
# Epoch 9/50 - Train Loss: 0.0140, Train Accuracy: 0.7422, Val Loss: 0.0137, Val Accuracy: 0.7069
# Epoch 10/50 - Train Loss: 0.0121, Train Accuracy: 0.8004, Val Loss: 0.0124, Val Accuracy: 0.7414
# Epoch 11/50 - Train Loss: 0.0104, Train Accuracy: 0.8585, Val Loss: 0.0112, Val Accuracy: 0.7931
# Epoch 12/50 - Train Loss: 0.0090, Train Accuracy: 0.8605, Val Loss: 0.0102, Val Accuracy: 0.8103
# Epoch 13/50 - Train Loss: 0.0080, Train Accuracy: 0.8857, Val Loss: 0.0092, Val Accuracy: 0.8448
# Epoch 14/50 - Train Loss: 0.0067, Train Accuracy: 0.9128, Val Loss: 0.0085, Val Accuracy: 0.8621
# Epoch 15/50 - Train Loss: 0.0064, Train Accuracy: 0.9205, Val Loss: 0.0077, Val Accuracy: 0.8621
# Epoch 16/50 - Train Loss: 0.0055, Train Accuracy: 0.9399, Val Loss: 0.0075, Val Accuracy: 0.8966
# Epoch 17/50 - Train Loss: 0.0048, Train Accuracy: 0.9399, Val Loss: 0.0068, Val Accuracy: 0.8621
# Epoch 18/50 - Train Loss: 0.0043, Train Accuracy: 0.9574, Val Loss: 0.0063, Val Accuracy: 0.8966
# Epoch 19/50 - Train Loss: 0.0037, Train Accuracy: 0.9632, Val Loss: 0.0059, Val Accuracy: 0.8966
# Epoch 20/50 - Train Loss: 0.0034, Train Accuracy: 0.9690, Val Loss: 0.0056, Val Accuracy: 0.8966
# Epoch 21/50 - Train Loss: 0.0031, Train Accuracy: 0.9748, Val Loss: 0.0052, Val Accuracy: 0.8966
# Epoch 22/50 - Train Loss: 0.0031, Train Accuracy: 0.9729, Val Loss: 0.0049, Val Accuracy: 0.9138
# Epoch 23/50 - Train Loss: 0.0025, Train Accuracy: 0.9826, Val Loss: 0.0049, Val Accuracy: 0.9138
# Epoch 24/50 - Train Loss: 0.0022, Train Accuracy: 0.9806, Val Loss: 0.0045, Val Accuracy: 0.9138
# Epoch 25/50 - Train Loss: 0.0022, Train Accuracy: 0.9845, Val Loss: 0.0042, Val Accuracy: 0.9483
# Epoch 26/50 - Train Loss: 0.0018, Train Accuracy: 0.9903, Val Loss: 0.0040, Val Accuracy: 0.9310
# Epoch 27/50 - Train Loss: 0.0015, Train Accuracy: 0.9942, Val Loss: 0.0038, Val Accuracy: 0.9310
# Epoch 28/50 - Train Loss: 0.0016, Train Accuracy: 0.9884, Val Loss: 0.0036, Val Accuracy: 0.9483
# Epoch 29/50 - Train Loss: 0.0015, Train Accuracy: 0.9884, Val Loss: 0.0036, Val Accuracy: 0.9310
# Epoch 30/50 - Train Loss: 0.0016, Train Accuracy: 0.9826, Val Loss: 0.0033, Val Accuracy: 0.9483
# Epoch 31/50 - Train Loss: 0.0013, Train Accuracy: 0.9903, Val Loss: 0.0031, Val Accuracy: 0.9310
# Epoch 32/50 - Train Loss: 0.0011, Train Accuracy: 0.9942, Val Loss: 0.0031, Val Accuracy: 0.9483
# Epoch 33/50 - Train Loss: 0.0013, Train Accuracy: 0.9903, Val Loss: 0.0034, Val Accuracy: 0.9310
# Epoch 34/50 - Train Loss: 0.0012, Train Accuracy: 0.9864, Val Loss: 0.0028, Val Accuracy: 0.9655
# Epoch 35/50 - Train Loss: 0.0011, Train Accuracy: 0.9922, Val Loss: 0.0039, Val Accuracy: 0.9310
# Epoch 36/50 - Train Loss: 0.0011, Train Accuracy: 0.9903, Val Loss: 0.0028, Val Accuracy: 0.9655
# Epoch 37/50 - Train Loss: 0.0010, Train Accuracy: 0.9922, Val Loss: 0.0037, Val Accuracy: 0.9310
# Epoch 38/50 - Train Loss: 0.0009, Train Accuracy: 0.9903, Val Loss: 0.0026, Val Accuracy: 0.9655
# Epoch 39/50 - Train Loss: 0.0008, Train Accuracy: 0.9922, Val Loss: 0.0029, Val Accuracy: 0.9483
# Epoch 40/50 - Train Loss: 0.0008, Train Accuracy: 0.9942, Val Loss: 0.0026, Val Accuracy: 0.9655
# Epoch 41/50 - Train Loss: 0.0007, Train Accuracy: 0.9942, Val Loss: 0.0026, Val Accuracy: 0.9483
# Epoch 42/50 - Train Loss: 0.0007, Train Accuracy: 0.9981, Val Loss: 0.0022, Val Accuracy: 0.9655
# Epoch 43/50 - Train Loss: 0.0006, Train Accuracy: 0.9981, Val Loss: 0.0027, Val Accuracy: 0.9483
# Epoch 44/50 - Train Loss: 0.0006, Train Accuracy: 1.0000, Val Loss: 0.0021, Val Accuracy: 0.9655
# Epoch 45/50 - Train Loss: 0.0006, Train Accuracy: 0.9942, Val Loss: 0.0021, Val Accuracy: 0.9655
# Epoch 46/50 - Train Loss: 0.0005, Train Accuracy: 1.0000, Val Loss: 0.0020, Val Accuracy: 0.9483
# Epoch 47/50 - Train Loss: 0.0006, Train Accuracy: 0.9981, Val Loss: 0.0019, Val Accuracy: 0.9655
# Epoch 48/50 - Train Loss: 0.0006, Train Accuracy: 0.9981, Val Loss: 0.0025, Val Accuracy: 0.9483
# Epoch 49/50 - Train Loss: 0.0005, Train Accuracy: 1.0000, Val Loss: 0.0025, Val Accuracy: 0.9483
# Epoch 50/50 - Train Loss: 0.0005, Train Accuracy: 1.0000, Val Loss: 0.0020, Val Accuracy: 0.9655
# Processing Fold 5...
# Epoch 1/50 - Train Loss: 0.0244, Train Accuracy: 0.2553, Val Loss: 0.0238, Val Accuracy: 0.4211
# Epoch 2/50 - Train Loss: 0.0236, Train Accuracy: 0.3308, Val Loss: 0.0232, Val Accuracy: 0.4211
# Epoch 3/50 - Train Loss: 0.0231, Train Accuracy: 0.3636, Val Loss: 0.0223, Val Accuracy: 0.4561
# Epoch 4/50 - Train Loss: 0.0220, Train Accuracy: 0.4468, Val Loss: 0.0211, Val Accuracy: 0.7193
# Epoch 5/50 - Train Loss: 0.0205, Train Accuracy: 0.5803, Val Loss: 0.0197, Val Accuracy: 0.7018
# Epoch 6/50 - Train Loss: 0.0190, Train Accuracy: 0.6112, Val Loss: 0.0179, Val Accuracy: 0.7719
# Epoch 7/50 - Train Loss: 0.0172, Train Accuracy: 0.6925, Val Loss: 0.0162, Val Accuracy: 0.7544
# Epoch 8/50 - Train Loss: 0.0155, Train Accuracy: 0.7273, Val Loss: 0.0142, Val Accuracy: 0.8070
# Epoch 9/50 - Train Loss: 0.0136, Train Accuracy: 0.7660, Val Loss: 0.0123, Val Accuracy: 0.8070
# Epoch 10/50 - Train Loss: 0.0122, Train Accuracy: 0.7988, Val Loss: 0.0108, Val Accuracy: 0.8596
# Epoch 11/50 - Train Loss: 0.0102, Train Accuracy: 0.8665, Val Loss: 0.0093, Val Accuracy: 0.8596
# Epoch 12/50 - Train Loss: 0.0089, Train Accuracy: 0.8665, Val Loss: 0.0081, Val Accuracy: 0.8772
# Epoch 13/50 - Train Loss: 0.0078, Train Accuracy: 0.8975, Val Loss: 0.0071, Val Accuracy: 0.8772
# Epoch 14/50 - Train Loss: 0.0066, Train Accuracy: 0.9207, Val Loss: 0.0064, Val Accuracy: 0.8947
# Epoch 15/50 - Train Loss: 0.0060, Train Accuracy: 0.9323, Val Loss: 0.0055, Val Accuracy: 0.8947
# Epoch 16/50 - Train Loss: 0.0050, Train Accuracy: 0.9400, Val Loss: 0.0048, Val Accuracy: 0.9298
# Epoch 17/50 - Train Loss: 0.0046, Train Accuracy: 0.9497, Val Loss: 0.0043, Val Accuracy: 0.9298
# Epoch 18/50 - Train Loss: 0.0042, Train Accuracy: 0.9555, Val Loss: 0.0039, Val Accuracy: 0.9474
# Epoch 19/50 - Train Loss: 0.0037, Train Accuracy: 0.9691, Val Loss: 0.0034, Val Accuracy: 0.9298
# Epoch 20/50 - Train Loss: 0.0033, Train Accuracy: 0.9691, Val Loss: 0.0033, Val Accuracy: 0.9474
# Epoch 21/50 - Train Loss: 0.0028, Train Accuracy: 0.9768, Val Loss: 0.0027, Val Accuracy: 0.9825
# Epoch 22/50 - Train Loss: 0.0028, Train Accuracy: 0.9729, Val Loss: 0.0025, Val Accuracy: 0.9825
# Epoch 23/50 - Train Loss: 0.0025, Train Accuracy: 0.9749, Val Loss: 0.0023, Val Accuracy: 0.9825
# Epoch 24/50 - Train Loss: 0.0021, Train Accuracy: 0.9845, Val Loss: 0.0020, Val Accuracy: 0.9825
# Epoch 25/50 - Train Loss: 0.0019, Train Accuracy: 0.9768, Val Loss: 0.0020, Val Accuracy: 0.9825
# Epoch 26/50 - Train Loss: 0.0017, Train Accuracy: 0.9787, Val Loss: 0.0016, Val Accuracy: 1.0000
# Epoch 27/50 - Train Loss: 0.0016, Train Accuracy: 0.9884, Val Loss: 0.0018, Val Accuracy: 0.9825
# Epoch 28/50 - Train Loss: 0.0015, Train Accuracy: 0.9865, Val Loss: 0.0014, Val Accuracy: 1.0000
# Epoch 29/50 - Train Loss: 0.0014, Train Accuracy: 0.9923, Val Loss: 0.0015, Val Accuracy: 1.0000
# Epoch 30/50 - Train Loss: 0.0015, Train Accuracy: 0.9845, Val Loss: 0.0013, Val Accuracy: 1.0000
# Epoch 31/50 - Train Loss: 0.0013, Train Accuracy: 0.9865, Val Loss: 0.0012, Val Accuracy: 1.0000
# Epoch 32/50 - Train Loss: 0.0012, Train Accuracy: 0.9903, Val Loss: 0.0010, Val Accuracy: 1.0000
# Epoch 33/50 - Train Loss: 0.0011, Train Accuracy: 0.9923, Val Loss: 0.0010, Val Accuracy: 1.0000
# Epoch 34/50 - Train Loss: 0.0010, Train Accuracy: 0.9961, Val Loss: 0.0009, Val Accuracy: 1.0000
# Epoch 35/50 - Train Loss: 0.0010, Train Accuracy: 0.9961, Val Loss: 0.0010, Val Accuracy: 1.0000
# Epoch 36/50 - Train Loss: 0.0009, Train Accuracy: 0.9903, Val Loss: 0.0009, Val Accuracy: 1.0000
# Epoch 37/50 - Train Loss: 0.0009, Train Accuracy: 0.9961, Val Loss: 0.0009, Val Accuracy: 1.0000
# Epoch 38/50 - Train Loss: 0.0007, Train Accuracy: 0.9981, Val Loss: 0.0007, Val Accuracy: 1.0000
# Epoch 39/50 - Train Loss: 0.0008, Train Accuracy: 0.9961, Val Loss: 0.0007, Val Accuracy: 1.0000
# Epoch 40/50 - Train Loss: 0.0007, Train Accuracy: 0.9961, Val Loss: 0.0007, Val Accuracy: 1.0000
# Epoch 41/50 - Train Loss: 0.0006, Train Accuracy: 1.0000, Val Loss: 0.0005, Val Accuracy: 1.0000
# Epoch 42/50 - Train Loss: 0.0007, Train Accuracy: 1.0000, Val Loss: 0.0007, Val Accuracy: 1.0000
# Epoch 43/50 - Train Loss: 0.0006, Train Accuracy: 0.9981, Val Loss: 0.0004, Val Accuracy: 1.0000
# Epoch 44/50 - Train Loss: 0.0006, Train Accuracy: 0.9981, Val Loss: 0.0005, Val Accuracy: 1.0000
# Epoch 45/50 - Train Loss: 0.0006, Train Accuracy: 0.9961, Val Loss: 0.0005, Val Accuracy: 1.0000
# Epoch 46/50 - Train Loss: 0.0006, Train Accuracy: 0.9961, Val Loss: 0.0004, Val Accuracy: 1.0000
# Epoch 47/50 - Train Loss: 0.0005, Train Accuracy: 1.0000, Val Loss: 0.0007, Val Accuracy: 1.0000
# Epoch 48/50 - Train Loss: 0.0004, Train Accuracy: 0.9981, Val Loss: 0.0004, Val Accuracy: 1.0000
# Epoch 49/50 - Train Loss: 0.0005, Train Accuracy: 0.9981, Val Loss: 0.0004, Val Accuracy: 1.0000
# Epoch 50/50 - Train Loss: 0.0005, Train Accuracy: 0.9942, Val Loss: 0.0004, Val Accuracy: 1.0000
# Processing Fold 6...
# Epoch 1/50 - Train Loss: 0.0248, Train Accuracy: 0.2418, Val Loss: 0.0240, Val Accuracy: 0.2807
# Epoch 2/50 - Train Loss: 0.0237, Train Accuracy: 0.3133, Val Loss: 0.0234, Val Accuracy: 0.4561
# Epoch 3/50 - Train Loss: 0.0231, Train Accuracy: 0.3946, Val Loss: 0.0227, Val Accuracy: 0.4737
# Epoch 4/50 - Train Loss: 0.0222, Train Accuracy: 0.4391, Val Loss: 0.0218, Val Accuracy: 0.5614
# Epoch 5/50 - Train Loss: 0.0212, Train Accuracy: 0.4913, Val Loss: 0.0205, Val Accuracy: 0.5439
# Epoch 6/50 - Train Loss: 0.0195, Train Accuracy: 0.5996, Val Loss: 0.0190, Val Accuracy: 0.6140
# Epoch 7/50 - Train Loss: 0.0177, Train Accuracy: 0.6615, Val Loss: 0.0174, Val Accuracy: 0.6667
# Epoch 8/50 - Train Loss: 0.0159, Train Accuracy: 0.7137, Val Loss: 0.0159, Val Accuracy: 0.6667
# Epoch 9/50 - Train Loss: 0.0144, Train Accuracy: 0.7447, Val Loss: 0.0145, Val Accuracy: 0.7368
# Epoch 10/50 - Train Loss: 0.0130, Train Accuracy: 0.7853, Val Loss: 0.0132, Val Accuracy: 0.7719
# Epoch 11/50 - Train Loss: 0.0109, Train Accuracy: 0.8414, Val Loss: 0.0118, Val Accuracy: 0.7895
# Epoch 12/50 - Train Loss: 0.0096, Train Accuracy: 0.8646, Val Loss: 0.0106, Val Accuracy: 0.8246
# Epoch 13/50 - Train Loss: 0.0086, Train Accuracy: 0.8859, Val Loss: 0.0095, Val Accuracy: 0.8596
# Epoch 14/50 - Train Loss: 0.0073, Train Accuracy: 0.9014, Val Loss: 0.0088, Val Accuracy: 0.8421
# Epoch 15/50 - Train Loss: 0.0065, Train Accuracy: 0.9226, Val Loss: 0.0080, Val Accuracy: 0.8421
# Epoch 16/50 - Train Loss: 0.0055, Train Accuracy: 0.9207, Val Loss: 0.0071, Val Accuracy: 0.8772
# Epoch 17/50 - Train Loss: 0.0049, Train Accuracy: 0.9342, Val Loss: 0.0065, Val Accuracy: 0.8772
# Epoch 18/50 - Train Loss: 0.0044, Train Accuracy: 0.9458, Val Loss: 0.0059, Val Accuracy: 0.9123
# Epoch 19/50 - Train Loss: 0.0040, Train Accuracy: 0.9594, Val Loss: 0.0056, Val Accuracy: 0.8947
# Epoch 20/50 - Train Loss: 0.0034, Train Accuracy: 0.9632, Val Loss: 0.0050, Val Accuracy: 0.9298
# Epoch 21/50 - Train Loss: 0.0030, Train Accuracy: 0.9749, Val Loss: 0.0047, Val Accuracy: 0.9298
# Epoch 22/50 - Train Loss: 0.0028, Train Accuracy: 0.9729, Val Loss: 0.0044, Val Accuracy: 0.9298
# Epoch 23/50 - Train Loss: 0.0025, Train Accuracy: 0.9729, Val Loss: 0.0043, Val Accuracy: 0.8947
# Epoch 24/50 - Train Loss: 0.0023, Train Accuracy: 0.9807, Val Loss: 0.0041, Val Accuracy: 0.9123
# Epoch 25/50 - Train Loss: 0.0022, Train Accuracy: 0.9826, Val Loss: 0.0041, Val Accuracy: 0.9123
# Epoch 26/50 - Train Loss: 0.0020, Train Accuracy: 0.9845, Val Loss: 0.0037, Val Accuracy: 0.9123
# Epoch 27/50 - Train Loss: 0.0020, Train Accuracy: 0.9729, Val Loss: 0.0035, Val Accuracy: 0.9123
# Epoch 28/50 - Train Loss: 0.0015, Train Accuracy: 0.9865, Val Loss: 0.0041, Val Accuracy: 0.9298
# Epoch 29/50 - Train Loss: 0.0017, Train Accuracy: 0.9787, Val Loss: 0.0032, Val Accuracy: 0.9298
# Epoch 30/50 - Train Loss: 0.0016, Train Accuracy: 0.9845, Val Loss: 0.0037, Val Accuracy: 0.9298
# Epoch 31/50 - Train Loss: 0.0013, Train Accuracy: 0.9903, Val Loss: 0.0032, Val Accuracy: 0.9123
# Epoch 32/50 - Train Loss: 0.0013, Train Accuracy: 0.9923, Val Loss: 0.0035, Val Accuracy: 0.9298
# Epoch 33/50 - Train Loss: 0.0012, Train Accuracy: 0.9884, Val Loss: 0.0032, Val Accuracy: 0.9298
# Epoch 34/50 - Train Loss: 0.0010, Train Accuracy: 0.9961, Val Loss: 0.0034, Val Accuracy: 0.9298
# Epoch 35/50 - Train Loss: 0.0011, Train Accuracy: 0.9903, Val Loss: 0.0031, Val Accuracy: 0.9298
# Epoch 36/50 - Train Loss: 0.0009, Train Accuracy: 0.9923, Val Loss: 0.0035, Val Accuracy: 0.9298
# Epoch 37/50 - Train Loss: 0.0008, Train Accuracy: 0.9981, Val Loss: 0.0031, Val Accuracy: 0.9298
# Epoch 38/50 - Train Loss: 0.0009, Train Accuracy: 0.9942, Val Loss: 0.0031, Val Accuracy: 0.9298
# Epoch 39/50 - Train Loss: 0.0008, Train Accuracy: 0.9981, Val Loss: 0.0029, Val Accuracy: 0.9474
# Epoch 40/50 - Train Loss: 0.0007, Train Accuracy: 0.9961, Val Loss: 0.0029, Val Accuracy: 0.9298
# Epoch 41/50 - Train Loss: 0.0007, Train Accuracy: 0.9942, Val Loss: 0.0030, Val Accuracy: 0.9298
# Epoch 42/50 - Train Loss: 0.0007, Train Accuracy: 0.9923, Val Loss: 0.0029, Val Accuracy: 0.9298
# Epoch 43/50 - Train Loss: 0.0006, Train Accuracy: 0.9961, Val Loss: 0.0032, Val Accuracy: 0.9298
# Epoch 44/50 - Train Loss: 0.0005, Train Accuracy: 0.9981, Val Loss: 0.0031, Val Accuracy: 0.9298
# Epoch 45/50 - Train Loss: 0.0006, Train Accuracy: 0.9961, Val Loss: 0.0028, Val Accuracy: 0.9298
# Epoch 46/50 - Train Loss: 0.0004, Train Accuracy: 1.0000, Val Loss: 0.0027, Val Accuracy: 0.9298
# Epoch 47/50 - Train Loss: 0.0005, Train Accuracy: 1.0000, Val Loss: 0.0027, Val Accuracy: 0.9298
# Epoch 48/50 - Train Loss: 0.0005, Train Accuracy: 1.0000, Val Loss: 0.0030, Val Accuracy: 0.9298
# Epoch 49/50 - Train Loss: 0.0004, Train Accuracy: 1.0000, Val Loss: 0.0026, Val Accuracy: 0.9474
# Epoch 50/50 - Train Loss: 0.0004, Train Accuracy: 0.9981, Val Loss: 0.0035, Val Accuracy: 0.9298
# Processing Fold 7...
# Epoch 1/50 - Train Loss: 0.0246, Train Accuracy: 0.2340, Val Loss: 0.0240, Val Accuracy: 0.2807
# Epoch 2/50 - Train Loss: 0.0237, Train Accuracy: 0.2979, Val Loss: 0.0235, Val Accuracy: 0.4386
# Epoch 3/50 - Train Loss: 0.0232, Train Accuracy: 0.3752, Val Loss: 0.0229, Val Accuracy: 0.5789
# Epoch 4/50 - Train Loss: 0.0220, Train Accuracy: 0.4758, Val Loss: 0.0219, Val Accuracy: 0.5789
# Epoch 5/50 - Train Loss: 0.0207, Train Accuracy: 0.5300, Val Loss: 0.0207, Val Accuracy: 0.7193
# Epoch 6/50 - Train Loss: 0.0189, Train Accuracy: 0.6634, Val Loss: 0.0192, Val Accuracy: 0.7368
# Epoch 7/50 - Train Loss: 0.0175, Train Accuracy: 0.6983, Val Loss: 0.0176, Val Accuracy: 0.7544
# Epoch 8/50 - Train Loss: 0.0154, Train Accuracy: 0.7369, Val Loss: 0.0160, Val Accuracy: 0.7544
# Epoch 9/50 - Train Loss: 0.0138, Train Accuracy: 0.7679, Val Loss: 0.0144, Val Accuracy: 0.7895
# Epoch 10/50 - Train Loss: 0.0123, Train Accuracy: 0.8124, Val Loss: 0.0130, Val Accuracy: 0.8070
# Epoch 11/50 - Train Loss: 0.0106, Train Accuracy: 0.8298, Val Loss: 0.0117, Val Accuracy: 0.8070
# Epoch 12/50 - Train Loss: 0.0096, Train Accuracy: 0.8607, Val Loss: 0.0105, Val Accuracy: 0.8246
# Epoch 13/50 - Train Loss: 0.0082, Train Accuracy: 0.8975, Val Loss: 0.0097, Val Accuracy: 0.8421
# Epoch 14/50 - Train Loss: 0.0073, Train Accuracy: 0.8956, Val Loss: 0.0088, Val Accuracy: 0.8421
# Epoch 15/50 - Train Loss: 0.0064, Train Accuracy: 0.9168, Val Loss: 0.0079, Val Accuracy: 0.8421
# Epoch 16/50 - Train Loss: 0.0055, Train Accuracy: 0.9362, Val Loss: 0.0074, Val Accuracy: 0.8421
# Epoch 17/50 - Train Loss: 0.0048, Train Accuracy: 0.9555, Val Loss: 0.0070, Val Accuracy: 0.8772
# Epoch 18/50 - Train Loss: 0.0044, Train Accuracy: 0.9574, Val Loss: 0.0065, Val Accuracy: 0.8772
# Epoch 19/50 - Train Loss: 0.0038, Train Accuracy: 0.9613, Val Loss: 0.0061, Val Accuracy: 0.9298
# Epoch 20/50 - Train Loss: 0.0035, Train Accuracy: 0.9632, Val Loss: 0.0058, Val Accuracy: 0.8947
# Epoch 21/50 - Train Loss: 0.0031, Train Accuracy: 0.9787, Val Loss: 0.0059, Val Accuracy: 0.9123
# Epoch 22/50 - Train Loss: 0.0026, Train Accuracy: 0.9826, Val Loss: 0.0055, Val Accuracy: 0.9298
# Epoch 23/50 - Train Loss: 0.0023, Train Accuracy: 0.9749, Val Loss: 0.0056, Val Accuracy: 0.8947
# Epoch 24/50 - Train Loss: 0.0022, Train Accuracy: 0.9865, Val Loss: 0.0051, Val Accuracy: 0.9298
# Epoch 25/50 - Train Loss: 0.0021, Train Accuracy: 0.9826, Val Loss: 0.0057, Val Accuracy: 0.9123
# Epoch 26/50 - Train Loss: 0.0018, Train Accuracy: 0.9845, Val Loss: 0.0048, Val Accuracy: 0.9123
# Epoch 27/50 - Train Loss: 0.0016, Train Accuracy: 0.9903, Val Loss: 0.0055, Val Accuracy: 0.8947
# Epoch 28/50 - Train Loss: 0.0015, Train Accuracy: 0.9942, Val Loss: 0.0050, Val Accuracy: 0.9298
# Epoch 29/50 - Train Loss: 0.0014, Train Accuracy: 0.9942, Val Loss: 0.0051, Val Accuracy: 0.9298
# Epoch 30/50 - Train Loss: 0.0012, Train Accuracy: 0.9942, Val Loss: 0.0048, Val Accuracy: 0.9298
# Epoch 31/50 - Train Loss: 0.0012, Train Accuracy: 0.9961, Val Loss: 0.0047, Val Accuracy: 0.9298
# Epoch 32/50 - Train Loss: 0.0011, Train Accuracy: 0.9981, Val Loss: 0.0050, Val Accuracy: 0.9298
# Epoch 33/50 - Train Loss: 0.0011, Train Accuracy: 0.9923, Val Loss: 0.0048, Val Accuracy: 0.9298
# Epoch 34/50 - Train Loss: 0.0009, Train Accuracy: 0.9981, Val Loss: 0.0048, Val Accuracy: 0.9474
# Epoch 35/50 - Train Loss: 0.0010, Train Accuracy: 0.9942, Val Loss: 0.0047, Val Accuracy: 0.9298
# Epoch 36/50 - Train Loss: 0.0008, Train Accuracy: 1.0000, Val Loss: 0.0048, Val Accuracy: 0.9474
# Epoch 37/50 - Train Loss: 0.0008, Train Accuracy: 1.0000, Val Loss: 0.0048, Val Accuracy: 0.9298
# Epoch 38/50 - Train Loss: 0.0007, Train Accuracy: 0.9981, Val Loss: 0.0048, Val Accuracy: 0.9474
# Epoch 39/50 - Train Loss: 0.0006, Train Accuracy: 1.0000, Val Loss: 0.0047, Val Accuracy: 0.9474
# Epoch 40/50 - Train Loss: 0.0006, Train Accuracy: 0.9942, Val Loss: 0.0053, Val Accuracy: 0.9123
# Epoch 41/50 - Train Loss: 0.0006, Train Accuracy: 0.9981, Val Loss: 0.0048, Val Accuracy: 0.9298
# Epoch 42/50 - Train Loss: 0.0006, Train Accuracy: 1.0000, Val Loss: 0.0056, Val Accuracy: 0.9298
# Epoch 43/50 - Train Loss: 0.0006, Train Accuracy: 0.9961, Val Loss: 0.0047, Val Accuracy: 0.9474
# Epoch 44/50 - Train Loss: 0.0006, Train Accuracy: 0.9961, Val Loss: 0.0054, Val Accuracy: 0.9298
# Epoch 45/50 - Train Loss: 0.0006, Train Accuracy: 0.9961, Val Loss: 0.0050, Val Accuracy: 0.9474
# Epoch 46/50 - Train Loss: 0.0006, Train Accuracy: 1.0000, Val Loss: 0.0050, Val Accuracy: 0.9298
# Epoch 47/50 - Train Loss: 0.0004, Train Accuracy: 1.0000, Val Loss: 0.0048, Val Accuracy: 0.9474
# Epoch 48/50 - Train Loss: 0.0004, Train Accuracy: 1.0000, Val Loss: 0.0048, Val Accuracy: 0.9474
# Epoch 49/50 - Train Loss: 0.0005, Train Accuracy: 0.9961, Val Loss: 0.0049, Val Accuracy: 0.9474
# Epoch 50/50 - Train Loss: 0.0004, Train Accuracy: 1.0000, Val Loss: 0.0047, Val Accuracy: 0.9474
# Processing Fold 8...
# Epoch 1/50 - Train Loss: 0.0248, Train Accuracy: 0.2534, Val Loss: 0.0239, Val Accuracy: 0.4561
# Epoch 2/50 - Train Loss: 0.0237, Train Accuracy: 0.2921, Val Loss: 0.0234, Val Accuracy: 0.4386
# Epoch 3/50 - Train Loss: 0.0229, Train Accuracy: 0.3675, Val Loss: 0.0226, Val Accuracy: 0.5439
# Epoch 4/50 - Train Loss: 0.0219, Train Accuracy: 0.4371, Val Loss: 0.0215, Val Accuracy: 0.5789
# Epoch 5/50 - Train Loss: 0.0203, Train Accuracy: 0.5687, Val Loss: 0.0200, Val Accuracy: 0.6316
# Epoch 6/50 - Train Loss: 0.0190, Train Accuracy: 0.6228, Val Loss: 0.0183, Val Accuracy: 0.7018
# Epoch 7/50 - Train Loss: 0.0171, Train Accuracy: 0.6634, Val Loss: 0.0166, Val Accuracy: 0.7719
# Epoch 8/50 - Train Loss: 0.0151, Train Accuracy: 0.7292, Val Loss: 0.0149, Val Accuracy: 0.7368
# Epoch 9/50 - Train Loss: 0.0131, Train Accuracy: 0.8027, Val Loss: 0.0132, Val Accuracy: 0.7719
# Epoch 10/50 - Train Loss: 0.0122, Train Accuracy: 0.8046, Val Loss: 0.0118, Val Accuracy: 0.8070
# Epoch 11/50 - Train Loss: 0.0106, Train Accuracy: 0.8395, Val Loss: 0.0107, Val Accuracy: 0.8070
# Epoch 12/50 - Train Loss: 0.0096, Train Accuracy: 0.8491, Val Loss: 0.0096, Val Accuracy: 0.8246
# Epoch 13/50 - Train Loss: 0.0081, Train Accuracy: 0.8820, Val Loss: 0.0087, Val Accuracy: 0.8246
# Epoch 14/50 - Train Loss: 0.0068, Train Accuracy: 0.9188, Val Loss: 0.0078, Val Accuracy: 0.8421
# Epoch 15/50 - Train Loss: 0.0062, Train Accuracy: 0.9226, Val Loss: 0.0070, Val Accuracy: 0.8596
# Epoch 16/50 - Train Loss: 0.0054, Train Accuracy: 0.9420, Val Loss: 0.0063, Val Accuracy: 0.8772
# Epoch 17/50 - Train Loss: 0.0049, Train Accuracy: 0.9536, Val Loss: 0.0061, Val Accuracy: 0.8947
# Epoch 18/50 - Train Loss: 0.0042, Train Accuracy: 0.9613, Val Loss: 0.0053, Val Accuracy: 0.9123
# Epoch 19/50 - Train Loss: 0.0038, Train Accuracy: 0.9749, Val Loss: 0.0048, Val Accuracy: 0.9123
# Epoch 20/50 - Train Loss: 0.0033, Train Accuracy: 0.9749, Val Loss: 0.0043, Val Accuracy: 0.9123
# Epoch 21/50 - Train Loss: 0.0031, Train Accuracy: 0.9787, Val Loss: 0.0041, Val Accuracy: 0.9298
# Epoch 22/50 - Train Loss: 0.0028, Train Accuracy: 0.9787, Val Loss: 0.0038, Val Accuracy: 0.9298
# Epoch 23/50 - Train Loss: 0.0027, Train Accuracy: 0.9826, Val Loss: 0.0033, Val Accuracy: 0.9298
# Epoch 24/50 - Train Loss: 0.0022, Train Accuracy: 0.9826, Val Loss: 0.0034, Val Accuracy: 0.9649
# Epoch 25/50 - Train Loss: 0.0018, Train Accuracy: 0.9903, Val Loss: 0.0031, Val Accuracy: 0.9298
# Epoch 26/50 - Train Loss: 0.0021, Train Accuracy: 0.9845, Val Loss: 0.0032, Val Accuracy: 0.9474
# Epoch 27/50 - Train Loss: 0.0020, Train Accuracy: 0.9845, Val Loss: 0.0028, Val Accuracy: 0.9474
# Epoch 28/50 - Train Loss: 0.0015, Train Accuracy: 0.9903, Val Loss: 0.0027, Val Accuracy: 0.9474
# Epoch 29/50 - Train Loss: 0.0014, Train Accuracy: 0.9981, Val Loss: 0.0025, Val Accuracy: 0.9474
# Epoch 30/50 - Train Loss: 0.0015, Train Accuracy: 0.9826, Val Loss: 0.0024, Val Accuracy: 0.9474
# Epoch 31/50 - Train Loss: 0.0013, Train Accuracy: 0.9942, Val Loss: 0.0023, Val Accuracy: 0.9649
# Epoch 32/50 - Train Loss: 0.0012, Train Accuracy: 0.9826, Val Loss: 0.0026, Val Accuracy: 0.9474
# Epoch 33/50 - Train Loss: 0.0012, Train Accuracy: 0.9865, Val Loss: 0.0023, Val Accuracy: 0.9474
# Epoch 34/50 - Train Loss: 0.0011, Train Accuracy: 0.9942, Val Loss: 0.0024, Val Accuracy: 0.9474
# Epoch 35/50 - Train Loss: 0.0010, Train Accuracy: 0.9981, Val Loss: 0.0024, Val Accuracy: 0.9474
# Epoch 36/50 - Train Loss: 0.0008, Train Accuracy: 1.0000, Val Loss: 0.0022, Val Accuracy: 0.9474
# Epoch 37/50 - Train Loss: 0.0007, Train Accuracy: 1.0000, Val Loss: 0.0023, Val Accuracy: 0.9474
# Epoch 38/50 - Train Loss: 0.0008, Train Accuracy: 0.9981, Val Loss: 0.0021, Val Accuracy: 0.9649
# Epoch 39/50 - Train Loss: 0.0008, Train Accuracy: 0.9981, Val Loss: 0.0021, Val Accuracy: 0.9474
# Epoch 40/50 - Train Loss: 0.0006, Train Accuracy: 1.0000, Val Loss: 0.0020, Val Accuracy: 0.9649
# Epoch 41/50 - Train Loss: 0.0008, Train Accuracy: 0.9981, Val Loss: 0.0020, Val Accuracy: 0.9649
# Epoch 42/50 - Train Loss: 0.0005, Train Accuracy: 0.9981, Val Loss: 0.0018, Val Accuracy: 0.9649
# Epoch 43/50 - Train Loss: 0.0006, Train Accuracy: 0.9981, Val Loss: 0.0021, Val Accuracy: 0.9474
# Epoch 44/50 - Train Loss: 0.0006, Train Accuracy: 0.9961, Val Loss: 0.0019, Val Accuracy: 0.9649
# Epoch 45/50 - Train Loss: 0.0006, Train Accuracy: 0.9981, Val Loss: 0.0021, Val Accuracy: 0.9474
# Epoch 46/50 - Train Loss: 0.0005, Train Accuracy: 1.0000, Val Loss: 0.0019, Val Accuracy: 0.9649
# Epoch 47/50 - Train Loss: 0.0005, Train Accuracy: 0.9981, Val Loss: 0.0020, Val Accuracy: 0.9474
# Epoch 48/50 - Train Loss: 0.0005, Train Accuracy: 0.9961, Val Loss: 0.0023, Val Accuracy: 0.9649
# Epoch 49/50 - Train Loss: 0.0004, Train Accuracy: 1.0000, Val Loss: 0.0019, Val Accuracy: 0.9649
# Epoch 50/50 - Train Loss: 0.0004, Train Accuracy: 0.9981, Val Loss: 0.0018, Val Accuracy: 0.9649
# Processing Fold 9...
# Epoch 1/50 - Train Loss: 0.0246, Train Accuracy: 0.2650, Val Loss: 0.0237, Val Accuracy: 0.4386
# Epoch 2/50 - Train Loss: 0.0236, Train Accuracy: 0.3288, Val Loss: 0.0233, Val Accuracy: 0.3509
# Epoch 3/50 - Train Loss: 0.0229, Train Accuracy: 0.3636, Val Loss: 0.0224, Val Accuracy: 0.5088
# Epoch 4/50 - Train Loss: 0.0217, Train Accuracy: 0.4778, Val Loss: 0.0213, Val Accuracy: 0.6491
# Epoch 5/50 - Train Loss: 0.0203, Train Accuracy: 0.5667, Val Loss: 0.0200, Val Accuracy: 0.6491
# Epoch 6/50 - Train Loss: 0.0188, Train Accuracy: 0.6344, Val Loss: 0.0186, Val Accuracy: 0.7368
# Epoch 7/50 - Train Loss: 0.0169, Train Accuracy: 0.6789, Val Loss: 0.0170, Val Accuracy: 0.7544
# Epoch 8/50 - Train Loss: 0.0151, Train Accuracy: 0.7466, Val Loss: 0.0155, Val Accuracy: 0.7193
# Epoch 9/50 - Train Loss: 0.0131, Train Accuracy: 0.7698, Val Loss: 0.0140, Val Accuracy: 0.7368
# Epoch 10/50 - Train Loss: 0.0113, Train Accuracy: 0.8317, Val Loss: 0.0128, Val Accuracy: 0.7368
# Epoch 11/50 - Train Loss: 0.0103, Train Accuracy: 0.8356, Val Loss: 0.0114, Val Accuracy: 0.7719
# Epoch 12/50 - Train Loss: 0.0092, Train Accuracy: 0.8453, Val Loss: 0.0103, Val Accuracy: 0.8070
# Epoch 13/50 - Train Loss: 0.0079, Train Accuracy: 0.8723, Val Loss: 0.0093, Val Accuracy: 0.8070
# Epoch 14/50 - Train Loss: 0.0068, Train Accuracy: 0.9091, Val Loss: 0.0083, Val Accuracy: 0.8246
# Epoch 15/50 - Train Loss: 0.0056, Train Accuracy: 0.9323, Val Loss: 0.0075, Val Accuracy: 0.8772
# Epoch 16/50 - Train Loss: 0.0052, Train Accuracy: 0.9381, Val Loss: 0.0071, Val Accuracy: 0.8421
# Epoch 17/50 - Train Loss: 0.0045, Train Accuracy: 0.9516, Val Loss: 0.0065, Val Accuracy: 0.8772
# Epoch 18/50 - Train Loss: 0.0044, Train Accuracy: 0.9574, Val Loss: 0.0060, Val Accuracy: 0.9123
# Epoch 19/50 - Train Loss: 0.0038, Train Accuracy: 0.9613, Val Loss: 0.0055, Val Accuracy: 0.9474
# Epoch 20/50 - Train Loss: 0.0034, Train Accuracy: 0.9594, Val Loss: 0.0049, Val Accuracy: 0.9123
# Epoch 21/50 - Train Loss: 0.0029, Train Accuracy: 0.9710, Val Loss: 0.0050, Val Accuracy: 0.8947
# Epoch 22/50 - Train Loss: 0.0028, Train Accuracy: 0.9691, Val Loss: 0.0044, Val Accuracy: 0.9123
# Epoch 23/50 - Train Loss: 0.0024, Train Accuracy: 0.9807, Val Loss: 0.0043, Val Accuracy: 0.9474
# Epoch 24/50 - Train Loss: 0.0022, Train Accuracy: 0.9865, Val Loss: 0.0039, Val Accuracy: 0.9123
# Epoch 25/50 - Train Loss: 0.0022, Train Accuracy: 0.9826, Val Loss: 0.0038, Val Accuracy: 0.9123
# Epoch 26/50 - Train Loss: 0.0020, Train Accuracy: 0.9845, Val Loss: 0.0035, Val Accuracy: 0.9123
# Epoch 27/50 - Train Loss: 0.0021, Train Accuracy: 0.9807, Val Loss: 0.0033, Val Accuracy: 0.9298
# Epoch 28/50 - Train Loss: 0.0016, Train Accuracy: 0.9884, Val Loss: 0.0034, Val Accuracy: 0.9298
# Epoch 29/50 - Train Loss: 0.0016, Train Accuracy: 0.9845, Val Loss: 0.0030, Val Accuracy: 0.9123
# Epoch 30/50 - Train Loss: 0.0015, Train Accuracy: 0.9884, Val Loss: 0.0028, Val Accuracy: 0.9123
# Epoch 31/50 - Train Loss: 0.0015, Train Accuracy: 0.9903, Val Loss: 0.0026, Val Accuracy: 0.9298
# Epoch 32/50 - Train Loss: 0.0012, Train Accuracy: 0.9923, Val Loss: 0.0026, Val Accuracy: 0.9298
# Epoch 33/50 - Train Loss: 0.0013, Train Accuracy: 0.9961, Val Loss: 0.0023, Val Accuracy: 0.9298
# Epoch 34/50 - Train Loss: 0.0011, Train Accuracy: 0.9942, Val Loss: 0.0022, Val Accuracy: 0.9474
# Epoch 35/50 - Train Loss: 0.0009, Train Accuracy: 0.9923, Val Loss: 0.0021, Val Accuracy: 0.9298
# Epoch 36/50 - Train Loss: 0.0008, Train Accuracy: 0.9981, Val Loss: 0.0020, Val Accuracy: 0.9474
# Epoch 37/50 - Train Loss: 0.0009, Train Accuracy: 0.9961, Val Loss: 0.0019, Val Accuracy: 0.9649
# Epoch 38/50 - Train Loss: 0.0009, Train Accuracy: 0.9942, Val Loss: 0.0021, Val Accuracy: 0.9649
# Epoch 39/50 - Train Loss: 0.0009, Train Accuracy: 0.9942, Val Loss: 0.0017, Val Accuracy: 0.9825
# Epoch 40/50 - Train Loss: 0.0007, Train Accuracy: 0.9961, Val Loss: 0.0021, Val Accuracy: 0.9649
# Epoch 41/50 - Train Loss: 0.0008, Train Accuracy: 0.9942, Val Loss: 0.0017, Val Accuracy: 0.9649
# Epoch 42/50 - Train Loss: 0.0007, Train Accuracy: 0.9981, Val Loss: 0.0017, Val Accuracy: 0.9649
# Epoch 43/50 - Train Loss: 0.0006, Train Accuracy: 0.9981, Val Loss: 0.0016, Val Accuracy: 0.9474
# Epoch 44/50 - Train Loss: 0.0007, Train Accuracy: 0.9903, Val Loss: 0.0015, Val Accuracy: 0.9649
# Epoch 45/50 - Train Loss: 0.0005, Train Accuracy: 1.0000, Val Loss: 0.0015, Val Accuracy: 0.9825
# Epoch 46/50 - Train Loss: 0.0006, Train Accuracy: 0.9961, Val Loss: 0.0013, Val Accuracy: 0.9649
# Epoch 47/50 - Train Loss: 0.0007, Train Accuracy: 0.9981, Val Loss: 0.0016, Val Accuracy: 0.9825
# Epoch 48/50 - Train Loss: 0.0005, Train Accuracy: 1.0000, Val Loss: 0.0013, Val Accuracy: 0.9825
# Epoch 49/50 - Train Loss: 0.0005, Train Accuracy: 0.9961, Val Loss: 0.0013, Val Accuracy: 0.9649
# Epoch 50/50 - Train Loss: 0.0004, Train Accuracy: 1.0000, Val Loss: 0.0014, Val Accuracy: 0.9649
# Processing Fold 10...
# Epoch 1/50 - Train Loss: 0.0249, Train Accuracy: 0.2360, Val Loss: 0.0237, Val Accuracy: 0.2982
# Epoch 2/50 - Train Loss: 0.0237, Train Accuracy: 0.3288, Val Loss: 0.0233, Val Accuracy: 0.4912
# Epoch 3/50 - Train Loss: 0.0230, Train Accuracy: 0.3598, Val Loss: 0.0224, Val Accuracy: 0.5965
# Epoch 4/50 - Train Loss: 0.0220, Train Accuracy: 0.4352, Val Loss: 0.0212, Val Accuracy: 0.6316
# Epoch 5/50 - Train Loss: 0.0207, Train Accuracy: 0.5397, Val Loss: 0.0196, Val Accuracy: 0.6667
# Epoch 6/50 - Train Loss: 0.0192, Train Accuracy: 0.6074, Val Loss: 0.0179, Val Accuracy: 0.7544
# Epoch 7/50 - Train Loss: 0.0173, Train Accuracy: 0.6344, Val Loss: 0.0161, Val Accuracy: 0.7895
# Epoch 8/50 - Train Loss: 0.0156, Train Accuracy: 0.7079, Val Loss: 0.0144, Val Accuracy: 0.7895
# Epoch 9/50 - Train Loss: 0.0138, Train Accuracy: 0.7524, Val Loss: 0.0128, Val Accuracy: 0.8596
# Epoch 10/50 - Train Loss: 0.0122, Train Accuracy: 0.8008, Val Loss: 0.0114, Val Accuracy: 0.8596
# Epoch 11/50 - Train Loss: 0.0108, Train Accuracy: 0.8259, Val Loss: 0.0102, Val Accuracy: 0.8596
# Epoch 12/50 - Train Loss: 0.0092, Train Accuracy: 0.8569, Val Loss: 0.0089, Val Accuracy: 0.8772
# Epoch 13/50 - Train Loss: 0.0077, Train Accuracy: 0.8994, Val Loss: 0.0079, Val Accuracy: 0.8947
# Epoch 14/50 - Train Loss: 0.0069, Train Accuracy: 0.9052, Val Loss: 0.0072, Val Accuracy: 0.8772
# Epoch 15/50 - Train Loss: 0.0061, Train Accuracy: 0.9072, Val Loss: 0.0063, Val Accuracy: 0.8772
# Epoch 16/50 - Train Loss: 0.0057, Train Accuracy: 0.9246, Val Loss: 0.0058, Val Accuracy: 0.8947
# Epoch 17/50 - Train Loss: 0.0051, Train Accuracy: 0.9362, Val Loss: 0.0052, Val Accuracy: 0.9123
# Epoch 18/50 - Train Loss: 0.0046, Train Accuracy: 0.9400, Val Loss: 0.0050, Val Accuracy: 0.8947
# Epoch 19/50 - Train Loss: 0.0039, Train Accuracy: 0.9555, Val Loss: 0.0045, Val Accuracy: 0.8947
# Epoch 20/50 - Train Loss: 0.0036, Train Accuracy: 0.9632, Val Loss: 0.0046, Val Accuracy: 0.9298
# Epoch 21/50 - Train Loss: 0.0033, Train Accuracy: 0.9671, Val Loss: 0.0045, Val Accuracy: 0.9123
# Epoch 22/50 - Train Loss: 0.0028, Train Accuracy: 0.9749, Val Loss: 0.0038, Val Accuracy: 0.9298
# Epoch 23/50 - Train Loss: 0.0025, Train Accuracy: 0.9826, Val Loss: 0.0040, Val Accuracy: 0.9298
# Epoch 24/50 - Train Loss: 0.0022, Train Accuracy: 0.9807, Val Loss: 0.0039, Val Accuracy: 0.9474
# Epoch 25/50 - Train Loss: 0.0019, Train Accuracy: 0.9826, Val Loss: 0.0038, Val Accuracy: 0.9123
# Epoch 26/50 - Train Loss: 0.0019, Train Accuracy: 0.9845, Val Loss: 0.0040, Val Accuracy: 0.9298
# Epoch 27/50 - Train Loss: 0.0018, Train Accuracy: 0.9768, Val Loss: 0.0037, Val Accuracy: 0.9298
# Epoch 28/50 - Train Loss: 0.0016, Train Accuracy: 0.9884, Val Loss: 0.0037, Val Accuracy: 0.9298
# Epoch 29/50 - Train Loss: 0.0014, Train Accuracy: 0.9923, Val Loss: 0.0033, Val Accuracy: 0.9298
# Epoch 30/50 - Train Loss: 0.0013, Train Accuracy: 0.9903, Val Loss: 0.0037, Val Accuracy: 0.9298
# Epoch 31/50 - Train Loss: 0.0014, Train Accuracy: 0.9884, Val Loss: 0.0031, Val Accuracy: 0.9474
# Epoch 32/50 - Train Loss: 0.0012, Train Accuracy: 0.9942, Val Loss: 0.0033, Val Accuracy: 0.9298
# Epoch 33/50 - Train Loss: 0.0012, Train Accuracy: 0.9903, Val Loss: 0.0031, Val Accuracy: 0.9298
# Epoch 34/50 - Train Loss: 0.0010, Train Accuracy: 0.9981, Val Loss: 0.0033, Val Accuracy: 0.9298
# Epoch 35/50 - Train Loss: 0.0008, Train Accuracy: 0.9981, Val Loss: 0.0030, Val Accuracy: 0.9298
# Epoch 36/50 - Train Loss: 0.0009, Train Accuracy: 0.9903, Val Loss: 0.0033, Val Accuracy: 0.9298
# Epoch 37/50 - Train Loss: 0.0009, Train Accuracy: 0.9981, Val Loss: 0.0030, Val Accuracy: 0.9474
# Epoch 38/50 - Train Loss: 0.0009, Train Accuracy: 0.9981, Val Loss: 0.0033, Val Accuracy: 0.9474
# Epoch 39/50 - Train Loss: 0.0008, Train Accuracy: 0.9942, Val Loss: 0.0028, Val Accuracy: 0.9474
# Epoch 40/50 - Train Loss: 0.0007, Train Accuracy: 0.9961, Val Loss: 0.0033, Val Accuracy: 0.9298
# Epoch 41/50 - Train Loss: 0.0008, Train Accuracy: 0.9942, Val Loss: 0.0029, Val Accuracy: 0.9649
# Epoch 42/50 - Train Loss: 0.0006, Train Accuracy: 0.9981, Val Loss: 0.0028, Val Accuracy: 0.9474
# Epoch 43/50 - Train Loss: 0.0006, Train Accuracy: 0.9961, Val Loss: 0.0029, Val Accuracy: 0.9649
# Epoch 44/50 - Train Loss: 0.0006, Train Accuracy: 0.9942, Val Loss: 0.0028, Val Accuracy: 0.9474
# Epoch 45/50 - Train Loss: 0.0005, Train Accuracy: 1.0000, Val Loss: 0.0029, Val Accuracy: 0.9474
# Epoch 46/50 - Train Loss: 0.0005, Train Accuracy: 0.9981, Val Loss: 0.0029, Val Accuracy: 0.9474
# Epoch 47/50 - Train Loss: 0.0004, Train Accuracy: 0.9981, Val Loss: 0.0029, Val Accuracy: 0.9474
# Epoch 48/50 - Train Loss: 0.0005, Train Accuracy: 1.0000, Val Loss: 0.0027, Val Accuracy: 0.9649
# Epoch 49/50 - Train Loss: 0.0004, Train Accuracy: 1.0000, Val Loss: 0.0028, Val Accuracy: 0.9649
# Epoch 50/50 - Train Loss: 0.0004, Train Accuracy: 0.9981, Val Loss: 0.0027, Val Accuracy: 0.9474

# %%
# Rata-rata metrik seluruh fold
avg_train_losses = np.mean(train_losses, axis=0)
avg_val_losses = np.mean(val_losses, axis=0)
avg_train_accuracies = np.mean(train_accuracies, axis=0)
avg_val_accuracies = np.mean(val_accuracies, axis=0)

# %%
# Plot Loss
plt.figure(figsize=(10, 6))
plt.plot(range(1, len(avg_train_losses) + 1), avg_train_losses, label="Train Loss", marker='o')
plt.plot(range(1, len(avg_val_losses) + 1), avg_val_losses, label="Validation Loss", marker='x')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Training vs Validation Loss")
plt.legend()
plt.grid()
plt.show()

# %%
# Plot Accuracy
plt.figure(figsize=(10, 6))
plt.plot(range(1, len(avg_train_accuracies) + 1), avg_train_accuracies, label="Train Accuracy", marker='o')
plt.plot(range(1, len(avg_val_accuracies) + 1), avg_val_accuracies, label="Validation Accuracy", marker='x')
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("Training vs Validation Accuracy")
plt.legend()
plt.grid()
plt.show()

# %%
print(f"Total Data: {len(X)}")
print(f"Training Data: {len(X_train)}")
print(f"Validation Data: {len(X_val)}")
# Out:
# Total Data: 574
# Training Data: 517
# Validation Data: 57
